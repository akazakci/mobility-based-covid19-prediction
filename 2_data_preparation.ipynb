# %% [markdown]
# # Data preparation

# %% [markdown]
# _Akin Kazakci, Mines ParisTech - PSL University_

# %% [markdown]
# Input:
# - (Facebook movement and population density dataset folders, French city codes (cities.csv)
#
# Output:
# - (movement_with_density_code_insee_'date'.csv)

# %% [markdown]
# We will have a look at the data and build a data structure where for each 'administrative zone' and 'time slice' (3x 8 hours per day), we will have 'movement (influx)' based on FB movement dataset and 'population density' (based on Facebook population density dataset). Facebook data does not give the real population density nor movement quantities but _indices_ (see later).

# %%
import pandas as pd
from os import listdir

# %%
# %load src/clean_FB_file_names.py
import pandas as pd
from os import listdir

path = 'administrative_movements/'
filenames = listdir(path)
filenames


def clean_FB_file_names(path, string_to_remove,prefix):
    import os
    for count, filename in enumerate(os.listdir(path)): 
        dst = str(filename).replace(string_to_remove,prefix)
        src = path + filename 
        dst = path+ dst 

        os.rename(src, dst) 


if __name__ == "__main__":
    
    #change args 
    
    string_to_remove = 'France Coronavirus Disease Prevention Map Mar 05 2020 Id  Movement between Administrative Regions_'
    prefix = 'm_'
    path = 'administrative_movements/' #or 'administrative_density/

    clean_FB_file_names(path, string_to_remove,prefix)

# %% [markdown]
# Here is the information given by Facebook:
#
# DataSet Id: 488834255146400
#
# What specific pairs of places (admin regions) are people moving between more or less often than we would expect based on pre-crisis levels?
#
# Movement maps illustrate patterns of movement of groups of people between different neighborhoods or cities over a period of several hours. By understanding these patterns, response organizations can better predict where resources will be needed, gain insight into patterns of evacuation, or predict where traffic will be most congested.
#
# The following metrics are available:
# * Date Time - The time period represented by the current map layer.
# * Starting Location - The region where the movement of the group started.
# * Ending Location: The region where the movement of the group ended.
# * Length (km) - The distance traveled in kilometers.
# * Baseline: People Moving - The total number of people who moved from Starting Location to Ending Location on average during the weeks before the disaster began.
# * Crisis: People Moving - The total number of people who moved from Starting Location to Ending Location during the time period specified
# * Difference - The difference between the number of people moving from Starting Location to Ending Location during the disaster compared to before the disaster.
# * Percent Change - The percentage difference between the number of people moving from Starting Location to Ending Location during the disaster compared to before the disaster.
# * Standard (Z) Score: The number of standard deviations by which the count of people moving during the crisis differs from the number of people moving during the baseline. Any z-value greater than 4 or smaller than -4 is clipped at 4 or -4.

# %% [markdown]
# I will start with movement data. Once it is loaded into a single dataframe, we need to add zip code for departments ('Code Insee') using an external file (cities.csv). This is a list of administrative zones in France with their map information (polygons) and various caracteristics.
#
# Before merging movement data with cities codes, we need to clean files we downloaded and build a data structure.

# %%
path = 'administrative_movements/'
filenames = listdir(path)

#Function to read files into a dataframe 
def build_frames(f, path):
    path = path+f
    df = pd.DataFrame()
    if f.endswith('.csv'):
        df = pd.read_csv(path)
        #print (path)
    return df

# %%
# build a list of dataframes
frames = [ build_frames(f, path) for f in filenames ]

# concat dataframes (we can sort data later cause all dfs are timestamped)
movement_data = pd.concat(frames)

# %% [markdown]
# Later we will regroup data per day, instead of 8 hours slices. Thus, we add a date column.

# %%
# add a date column, 
movement_data['date'] = [row.date() for row in pd.to_datetime(movement_data.date_time)]

# %%
#for some reason FB data contains rows from great britain, delete those
movement_data = movement_data[movement_data['country'] == 'FR']

# %%
# there are 16818 rows where start and end polygons are the same; I dropped those lines
movement_data = movement_data[movement_data['start_polygon_id'] != movement_data['end_polygon_id']]

# %%
movement_data.shape
# Out:
# (51027, 21)

# %%
movement_data.columns
# Out:
# Index(['geometry', 'date_time', 'start_polygon_id', 'start_polygon_name',
#        'end_polygon_id', 'end_polygon_name', 'length_km', 'tile_size',
#        'country', 'level', 'n_crisis', 'n_baseline', 'n_difference',
#        'percent_change', 'is_statistically_significant', 'z_score',
#        'start_lat', 'start_lon', 'end_lat', 'end_lon', 'date'],
#       dtype='object')

# %% [markdown]
# Let us load city codes and data. Obtaining this file required some work since Facebook polygons and France map does not always intersect.

# %%
city_codes = pd.read_csv('cities.csv', sep=';')

# %% [markdown]
# In the movement dataframe, we have starting and end polygons. So we need to add both departmental codes (two new columns).

# %%
# FIRST EXECUTE THIS
city_codes.rename(columns = {'geometry':'end_point', 'code_insee':'end_code_insee','polygon_id':'end_polygon_id'}, inplace = True) #',
city_codes = city_codes[['end_code_insee','end_polygon_id','end_point']]
city_codes.columns
# Out:
# Index(['end_code_insee', 'end_polygon_id', 'end_point'], dtype='object')

# %%
#movement_data.rename(columns = {'start_polygon_id':'polygon_id'}, inplace = True)
merge_attempt = pd.merge(movement_data, city_codes, how ='left', on='end_polygon_id')
merge_attempt#[movement_data['start_polygon_id']=='153026']
# Out:
#                                                 geometry        date_time  \
# 0      LINESTRING (6.4072265625 47.54678262206, 6.372...  2020-04-13 1600
# 1      LINESTRING (-2.00390625 48.60962767452532, -2....  2020-04-13 1600
# 2      LINESTRING (6.702952665441177 48.4702643598611...  2020-04-13 1600
# 3      LINESTRING (6.7998046875 48.308484700771565, 6...  2020-04-13 1600
# 4      LINESTRING (6.801060267857143 43.5682258217796...  2020-04-13 1600
# 5      LINESTRING (-2.07916259765625 48.4890987554892...  2020-04-13 1600
# 6      LINESTRING (6.845703125 47.52377930909915, 6.8...  2020-04-13 1600
# 7      LINESTRING (6.903076171875 47.61107882306799, ...  2020-04-13 1600
# 8      LINESTRING (6.9313742897727275 43.612189988350...  2020-04-13 1600
# 9      LINESTRING (7.1630859375 48.99334514816719, 7....  2020-04-13 1600
# 10     LINESTRING (7.169363839285714 48.9428933119510...  2020-04-13 1600
# 11     LINESTRING (-0.2021484375 43.34422109116603, 0...  2020-04-13 1600
# 12     LINESTRING (7.380227481617647 48.1401829323005...  2020-04-13 1600
# 13     LINESTRING (-0.21344866071428573 45.5304085851...  2020-04-13 1600
# 14     LINESTRING (0.043945312500000014 44.5587955082...  2020-04-13 1600
# 15     LINESTRING (0.0771484375 48.422708538878084, 0...  2020-04-13 1600
# 16     LINESTRING (0.08467511432926832 44.88351560884...  2020-04-13 1600
# 17     LINESTRING (0.10570629222972973 44.91515643959...  2020-04-13 1600
# 18     LINESTRING (0.1318359375 48.42919218945775, 0....  2020-04-13 1600
# 19     LINESTRING (0.3076171875 49.25530317527849, 0....  2020-04-13 1600
# 20     LINESTRING (0.4434481534090909 49.319809821061...  2020-04-13 1600
# 21     LINESTRING (0.5620374177631579 44.221918046150...  2020-04-13 1600
# 22     LINESTRING (0.9818307976973685 49.383825035207...  2020-04-13 1600
# 23     LINESTRING (1.0689233054577465 49.286732633260...  2020-04-13 1600
# 24     LINESTRING (1.2744140625 43.61220835165366, 1....  2020-04-13 1600
# 25     LINESTRING (1.3037109375 43.122354386343154, 1...  2020-04-13 1600
# 26     LINESTRING (1.34033203125 43.929490993416344, ...  2020-04-13 1600
# 27     LINESTRING (1.3497488839285714 43.757416053471...  2020-04-13 1600
# 28     LINESTRING (1.4250837053571428 48.802683497675...  2020-04-13 1600
# 29     LINESTRING (1.4741654829545454 48.709361529362...  2020-04-13 1600
# ...                                                  ...              ...
# 50997  LINESTRING (3.7265625 50.03877971549737, 3.695...  2020-03-11 0000
# 50998  LINESTRING (3.7316509046052633 49.378180256364...  2020-03-11 0000
# 50999  LINESTRING (3.732516381048387 49.9666817398526...  2020-03-11 0000
# 51000  LINESTRING (-0.9947620738636364 46.36345638162...  2020-03-11 0000
# 51001  LINESTRING (3.7353515625000004 46.649427750905...  2020-03-11 0000
# 51002  LINESTRING (-1.0074869791666667 46.96801330020...  2020-03-11 0000
# 51003  LINESTRING (3.7723581414473686 46.550856154533...  2020-03-11 0000
# 51004  LINESTRING (3.7784677181603774 48.607908999497...  2020-03-11 0000
# 51005  LINESTRING (3.8232421875 48.42658817430449, 3....  2020-03-11 0000
# 51006  LINESTRING (-1.0644934788223142 47.26060382408...  2020-03-11 0000
# 51007  LINESTRING (3.92333984375 49.197531299750466, ...  2020-03-11 0000
# 51008  LINESTRING (-1.0860770089285714 44.42477212462...  2020-03-11 0000
# 51009  LINESTRING (3.9990234375 49.23911249814392, 2....  2020-03-11 0000
# 51010  LINESTRING (4.013671875 49.23911249814391, 4.4...  2020-03-11 0000
# 51011  LINESTRING (4.018899762588339 43.6620693838510...  2020-03-11 0000
# 51012  LINESTRING (4.1607421875 46.09392038935229, 4....  2020-03-11 0000
# 51013  LINESTRING (4.224842712942478 43.7402120063005...  2020-03-11 0000
# 51014  LINESTRING (4.234921875 45.33987452185053, 4.3...  2020-03-11 0000
# 51015  LINESTRING (4.3113156582446805 49.507518814559...  2020-03-11 0000
# 51016  LINESTRING (4.3587890625 45.42845306954688, 4....  2020-03-11 0000
# 51017  LINESTRING (4.391150841346153 44.2306221697706...  2020-03-11 0000
# 51018  LINESTRING (-1.1520565257352942 49.20839740144...  2020-03-11 0000
# 51019  LINESTRING (4.460225007971939 45.5728974496349...  2020-03-11 0000
# 51020  LINESTRING (4.521344866071429 43.7846351219891...  2020-03-11 0000
# 51021  LINESTRING (4.5832375919117645 44.308118260936...  2020-03-11 0000
# 51022  LINESTRING (4.614257812499999 44.2346914155724...  2020-03-11 0000
# 51023  LINESTRING (4.614257812499999 44.3524902216368...  2020-03-11 0000
# 51024  LINESTRING (-1.2464488636363635 48.15267269752...  2020-03-11 0000
# 51025  LINESTRING (4.6462180397727275 45.343227457275...  2020-03-11 0000
# 51026  LINESTRING (4.648649796195652 48.7778346834882...  2020-03-11 0000
#
#        start_polygon_id     start_polygon_name  end_polygon_id  \
# 0                151058            Haute-Saône          151057
# 1                162813        Ille-et-Vilaine          162816
# 2                138785     Meurthe-et-Moselle          141764
# 3                141764                 Vosges          138785
# 4                132360                    Var          132356
# 5                162816          Côtes-d'Armor          162813
# 6                151057                  Doubs          153025
# 7                153025  Territoire de Belfort          151057
# 8                132356        Alpes-Maritimes          132360
# 9                141765                Moselle          138786
# 10               138786               Bas-Rhin          141765
# 11               155289   Pyrénées-Atlantiques          141782
# 12               138787              Haut-Rhin          138786
# 13               145783               Charente          145782
# 14               155291                Gironde          155287
# 15               162817                   Orne          162811
# 16               155291                Gironde          155290
# 17               155290               Dordogne          155291
# 18               162811                 Sarthe          162817
# 19               162818               Calvados          160252
# 20               160252                   Eure          162818
# 21               155287         Lot-et-Garonne          141783
# 22               160251         Seine-Maritime          160252
# 23               160252                   Eure          160251
# 24               141791          Haute-Garonne          141790
# 25               141792                 Ariège          141791
# 26               141783        Tarn-et-Garonne          141791
# 27               141791          Haute-Garonne          141783
# 28               143601           Eure-et-Loir          160252
# 29               143601           Eure-et-Loir          133651
# ...                 ...                    ...             ...
# 50997            166635                   Nord          166634
# 50998            166634                  Aisne          138788
# 50999            166634                  Aisne          166635
# 51000            162807                 Vendée          145782
# 51001            151061         Saône-et-Loire          157443
# 51002            162807                 Vendée          162809
# 51003            157443                 Allier          151061
# 51004            138788                  Marne          138790
# 51005            138790                   Aube          138788
# 51006            162809         Maine-et-Loire          162808
# 51007            138788                  Marne          166634
# 51008            155288                 Landes          155291
# 51009            138788                  Marne          133657
# 51010            138788                  Marne          138789
# 51011            153022                Hérault          153023
# 51012            155294                  Loire          151061
# 51013            153023                   Gard          153022
# 51014            153026            Haute-Loire          155294
# 51015            138789               Ardennes          138788
# 51016            155294                  Loire          153026
# 51017            153023                   Gard          155292
# 51018            160253                 Manche          162818
# 51019            155294                  Loire          157439
# 51020            153023                   Gard          132359
# 51021            155292                Ardèche          153023
# 51022            153023                   Gard          157437
# 51023            155292                Ardèche          132361
# 51024            162813        Ille-et-Vilaine          162810
# 51025            155294                  Loire          155292
# 51026            138788                  Marne          138791
#
#             end_polygon_name   length_km  tile_size country   level  ...  \
# 0                      Doubs   14.779808         12      FR  LEVEL3  ...
# 1              Côtes-d'Armor    7.262711         12      FR  LEVEL3  ...
# 2                     Vosges   13.670990         12      FR  LEVEL3  ...
# 3         Meurthe-et-Moselle   20.333646         12      FR  LEVEL3  ...
# 4            Alpes-Maritimes   11.988855         12      FR  LEVEL3  ...
# 5            Ille-et-Vilaine    6.455673         12      FR  LEVEL3  ...
# 6      Territoire de Belfort   12.739222         12      FR  LEVEL3  ...
# 7                      Doubs   11.385253         12      FR  LEVEL3  ...
# 8                        Var   12.412757         12      FR  LEVEL3  ...
# 9                   Bas-Rhin    1.552127         12      FR  LEVEL3  ...
# 10                   Moselle    2.896218         12      FR  LEVEL3  ...
# 11           Hautes-Pyrénées   17.989138         12      FR  LEVEL3  ...
# 12                  Bas-Rhin   12.855698         12      FR  LEVEL3  ...
# 13         Charente-Maritime   22.803061         12      FR  LEVEL3  ...
# 14            Lot-et-Garonne    7.338661         12      FR  LEVEL3  ...
# 15                    Sarthe    5.564483         12      FR  LEVEL3  ...
# 16                  Dordogne    3.656707         12      FR  LEVEL3  ...
# 17                   Gironde    2.786629         12      FR  LEVEL3  ...
# 18                      Orne    6.484831         12      FR  LEVEL3  ...
# 19                      Eure    5.195059         12      FR  LEVEL3  ...
# 20                  Calvados   12.047225         12      FR  LEVEL3  ...
# 21           Tarn-et-Garonne   33.724579         12      FR  LEVEL3  ...
# 22                      Eure    7.606484         12      FR  LEVEL3  ...
# 23            Seine-Maritime    8.522599         12      FR  LEVEL3  ...
# 24                      Gers   14.151798         12      FR  LEVEL3  ...
# 25             Haute-Garonne   23.342625         12      FR  LEVEL3  ...
# 26             Haute-Garonne   28.438875         12      FR  LEVEL3  ...
# 27           Tarn-et-Garonne   14.497159         12      FR  LEVEL3  ...
# 28                      Eure    5.886085         12      FR  LEVEL3  ...
# 29                  Yvelines   24.872903         12      FR  LEVEL3  ...
# ...                      ...         ...        ...     ...     ...  ...
# 50997                  Aisne   11.988928         12      FR  LEVEL3  ...
# 50998                  Marne   24.562007         12      FR  LEVEL3  ...
# 50999                   Nord   12.967448         12      FR  LEVEL3  ...
# 51000      Charente-Maritime   21.423670         12      FR  LEVEL3  ...
# 51001                 Allier   16.311134         12      FR  LEVEL3  ...
# 51002         Maine-et-Loire   12.133574         12      FR  LEVEL3  ...
# 51003         Saône-et-Loire    5.797546         12      FR  LEVEL3  ...
# 51004                   Aube   15.828212         12      FR  LEVEL3  ...
# 51005                  Marne   15.811850         12      FR  LEVEL3  ...
# 51006       Loire-Atlantique   27.353869         12      FR  LEVEL3  ...
# 51007                  Aisne   26.676600         12      FR  LEVEL3  ...
# 51008                Gironde   26.045349         12      FR  LEVEL3  ...
# 51009                  Paris  128.533521         12      FR  LEVEL3  ...
# 51010               Ardennes   45.775645         12      FR  LEVEL3  ...
# 51011                   Gard   20.958921         12      FR  LEVEL3  ...
# 51012         Saône-et-Loire   16.905817         12      FR  LEVEL3  ...
# 51013                Hérault   21.087542         12      FR  LEVEL3  ...
# 51014                  Loire   14.678361         12      FR  LEVEL3  ...
# 51015                  Marne   34.206610         12      FR  LEVEL3  ...
# 51016            Haute-Loire   13.097012         12      FR  LEVEL3  ...
# 51017                Ardèche   12.795428         12      FR  LEVEL3  ...
# 51018               Calvados   27.663345         12      FR  LEVEL3  ...
# 51019                  Rhône   30.645949         12      FR  LEVEL3  ...
# 51020       Bouches-du-Rhône   13.762803         12      FR  LEVEL3  ...
# 51021                   Gard   10.588422         12      FR  LEVEL3  ...
# 51022                  Drôme   16.744667         12      FR  LEVEL3  ...
# 51023               Vaucluse    8.556629         12      FR  LEVEL3  ...
# 51024                Mayenne   25.248230         12      FR  LEVEL3  ...
# 51025                Ardèche   10.992081         12      FR  LEVEL3  ...
# 51026            Haute-Marne   26.530295         12      FR  LEVEL3  ...
#
#        percent_change  is_statistically_significant   z_score  start_lat  \
# 0          -90.985577                             0 -4.000000  47.641297
# 1          -96.890547                             0 -4.000000  48.155998
# 2          -94.109494                             0 -4.000000  48.788773
# 3          -91.575818                             0 -4.000000  48.196375
# 4          -87.811956                             0 -4.000000  43.441394
# 5          -86.688852                             0 -4.000000  48.441082
# 6          -96.736292                             0 -4.000000  47.165940
# 7          -96.460449                             0 -4.000000  47.631549
# 8          -95.963796                             0 -4.000000  43.937499
# 9          -92.027335                             0 -4.000000  49.037552
# 10         -97.622821                             0 -4.000000  48.671473
# 11         -89.690722                             0 -4.000000  43.256602
# 12         -97.137746                             0 -4.000000  47.859497
# 13         -96.177370                             0 -4.000000  45.718712
# 14         -90.491284                             0 -4.000000  44.839424
# 15         -89.426692                             0 -4.000000  48.623163
# 16         -89.225244                             0 -4.000000  44.839424
# 17         -82.965009                             0 -4.000000  45.104973
# 18         -92.336371                             0 -4.000000  47.994959
# 19         -95.118550                             0 -4.000000  49.099749
# 20         -84.351714                             0 -4.000000  49.113863
# 21         -80.633803                             0 -4.000000  44.367986
# 22         -96.471451                             0 -4.000000  49.654680
# 23         -93.755421                             0 -4.000000  49.113863
# 24         -94.875549                             0 -4.000000  43.358859
# 25         -90.551181                             0 -4.000000  42.921067
# 26         -96.522603                             0 -4.000000  44.085848
# 27         -97.334518                             0 -4.000000  43.358859
# 28         -93.255132                             0 -4.000000  48.388031
# 29         -89.377845                             0 -4.000000  48.388031
# ...               ...                           ...       ...        ...
# 50997       12.716763                             0  0.464317  50.448403
# 50998       -4.081633                             0 -0.335673  49.561332
# 50999      -23.255814                             0 -1.290994  49.561332
# 51000      -17.266187                             0 -0.680868  46.674376
# 51001      -50.000000                             0 -2.028370  46.644782
# 51002        7.843137                             0  0.522976  46.674376
# 51003      -26.056338                             0 -1.165680  46.393674
# 51004        5.263158                             0  0.497613  48.949517
# 51005      -23.312883                             0 -1.220106  48.304827
# 51006       15.458015                             0  0.674590  47.391116
# 51007      -29.118774                             0 -1.492637  48.949517
# 51008       20.967742                             0  1.116281  43.966067
# 51009       14.035088                             0  0.730297  48.949517
# 51010      -11.504425                             0 -0.962303  48.949517
# 51011        1.785714                             0  0.668153  43.579408
# 51012       55.844156                             0  1.537186  45.727822
# 51013       -0.935126                             0 -0.105346  43.993790
# 51014        9.114812                             0  2.322609  45.128017
# 51015       34.005764                             0  2.443268  49.616143
# 51016       -0.527009                             0 -0.054983  45.727822
# 51017       25.000000                             0  0.618853  43.993790
# 51018       33.165829                             0  1.818313  49.081618
# 51019       -2.536052                             0 -0.339868  45.727822
# 51020      -14.473684                             0 -2.116789  43.993790
# 51021       53.225806                             0  1.844756  44.752769
# 51022       15.384615                             0  0.531858  43.993790
# 51023       49.253731                             0  1.170389  44.752769
# 51024       44.578313                             0  2.029111  48.155998
# 51025       -2.857143                             0 -0.324443  45.727822
# 51026       42.857143                             0  1.080661  48.949517
#
#        start_lon    end_lat   end_lon        date  end_code_insee  \
# 0       6.087378  47.165940  6.362767  2020-04-13              25
# 1      -1.638757  48.441082 -2.863818  2020-04-13              22
# 2       6.161936  48.196375  6.380097  2020-04-13              88
# 3       6.380097  48.788773  6.161936  2020-04-13              54
# 4       6.244436  43.937499  7.116540  2020-04-13              06
# 5      -2.863818  48.155998 -1.638757  2020-04-13              35
# 6       6.362767  47.631549  6.928786  2020-04-13              90
# 7       6.928786  47.165940  6.362767  2020-04-13              25
# 8       7.116540  43.441394  6.244436  2020-04-13              83
# 9       6.661347  48.671473  7.551988  2020-04-13              67
# 10      7.551988  49.037552  6.661347  2020-04-13              57
# 11     -0.761165  43.053705  0.163820  2020-04-13              65
# 12      7.273705  48.671473  7.551988  2020-04-13              67
# 13      0.203073  45.775443 -0.681424  2020-04-13              17
# 14     -0.584941  44.367986  0.460769  2020-04-13              47
# 15      0.127644  47.994959  0.222374  2020-04-13              72
# 16     -0.584941  45.104973  0.741190  2020-04-13              24
# 17      0.741190  44.839424 -0.584941  2020-04-13              33
# 18      0.222374  48.623163  0.127644  2020-04-13              61
# 19     -0.362833  49.113863  0.996116  2020-04-13              27
# 20      0.996116  49.099749 -0.362833  2020-04-13              14
# 21      0.460769  44.085848  1.282550  2020-04-13              82
# 22      1.026413  49.113863  0.996116  2020-04-13              27
# 23      0.996116  49.654680  1.026413  2020-04-13              76
# 24      1.174836  43.692952  0.452960  2020-04-13              32
# 25      1.503457  43.358859  1.174836  2020-04-13              31
# 26      1.282550  43.358859  1.174836  2020-04-13              31
# 27      1.174836  44.085848  1.282550  2020-04-13              82
# 28      1.369855  49.113863  0.996116  2020-04-13              27
# 29      1.369855  48.815290  1.841107  2020-04-13              78
# ...          ...        ...       ...         ...             ...
# 50997   3.213983  49.561332  3.559737  2020-03-11              02
# 50998   3.559737  48.949517  4.238729  2020-03-11              51
# 50999   3.559737  50.448403  3.213983  2020-03-11              59
# 51000  -1.299265  45.775443 -0.681424  2020-03-11              17
# 51001   4.542793  46.393674  3.187571  2020-03-11              03
# 51002  -1.299265  47.391116 -0.564002  2020-03-11              49
# 51003   3.187571  46.644782  4.542793  2020-03-11              71
# 51004   4.238729  48.304827  4.161301  2020-03-11              10
# 51005   4.161301  48.949517  4.238729  2020-03-11              51
# 51006  -0.564002  47.361340 -1.683657  2020-03-11              44
# 51007   4.238729  49.561332  3.559737  2020-03-11              02
# 51008  -0.784561  44.839424 -0.584941  2020-03-11              33
# 51009   4.238729  48.856618  2.342937  2020-03-11              75
# 51010   4.238729  49.616143  4.640793  2020-03-11              08
# 51011   3.368403  43.993790  4.179392  2020-03-11              30
# 51012   4.164816  46.644782  4.542793  2020-03-11              71
# 51013   4.179392  43.579408  3.368403  2020-03-11              34
# 51014   3.806065  45.727822  4.164816  2020-03-11              42
# 51015   4.640793  48.949517  4.238729  2020-03-11              51
# 51016   4.164816  45.128017  3.806065  2020-03-11              43
# 51017   4.179392  44.752769  4.425621  2020-03-11              07
# 51018  -1.330021  49.099749 -0.362833  2020-03-11              14
# 51019   4.164816  45.871201  4.640869  2020-03-11             69D
# 51020   4.179392  43.545358  5.084388  2020-03-11              13
# 51021   4.425621  43.993790  4.179392  2020-03-11              30
# 51022   4.179392  44.685231  5.167418  2020-03-11              26
# 51023   4.425621  44.007107  5.177108  2020-03-11              84
# 51024  -1.638757  48.147313 -0.657627  2020-03-11              53
# 51025   4.164816  44.752769  4.425621  2020-03-11              07
# 51026   4.238729  48.110463  5.225542  2020-03-11              52
#
#                                          end_point
# 0            POINT (6.3627673495422 47.1659398827)
# 1         POINT (-2.8638179631241 48.441081670621)
# 2        POINT (6.380097025155799 48.196374688122)
# 3        POINT (6.161935534586201 48.788772923342)
# 4          POINT (7.1165396780881 43.937498635409)
# 5         POINT (-1.6387567734127 48.155998402337)
# 6            POINT (6.928786304666 47.63154940893)
# 7            POINT (6.3627673495422 47.1659398827)
# 8          POINT (6.2444358836793 43.441394031236)
# 9      POINT (7.551988030043201 48.67147272631099)
# 10         POINT (6.6613465360916 49.037552167624)
# 11      POINT (0.16381986381306 43.05370497053701)
# 12     POINT (7.551988030043201 48.67147272631099)
# 13     POINT (-0.6814237295999399 45.775443416232)
# 14         POINT (0.4607685460176 44.367985977796)
# 15      POINT (0.22237443271669 47.99495905390199)
# 16         POINT (0.7411895421848 45.104972883166)
# 17       POINT (-0.58494064492909 44.839423842689)
# 18        POINT (0.12764427313879 48.623162894016)
# 19        POINT (0.99611619709287 49.113862614453)
# 20        POINT (-0.36283271663128 49.09974939647)
# 21         POINT (1.2825500710075 44.085848329383)
# 22        POINT (0.99611619709287 49.113862614453)
# 23         POINT (1.0264132376398 49.654679612631)
# 24       POINT (0.4529599652369199 43.69295211729)
# 25       POINT (1.1748362749038 43.35885949184399)
# 26       POINT (1.1748362749038 43.35885949184399)
# 27         POINT (1.2825500710075 44.085848329383)
# 28        POINT (0.99611619709287 49.113862614453)
# 29       POINT (1.8411073611173 48.81528983084699)
# ...                                            ...
# 50997        POINT (3.5597374607055 49.5613321662)
# 50998      POINT (4.2387289197378 48.949516956994)
# 50999      POINT (3.2139829921559 50.448402896612)
# 51000  POINT (-0.6814237295999399 45.775443416232)
# 51001    POINT (3.1875714855729 46.39367430400601)
# 51002  POINT (-0.5640020651848199 47.391116158314)
# 51003    POINT (4.5427933362059 46.64478238347399)
# 51004      POINT (4.1613013956674 48.304827381208)
# 51005      POINT (4.2387289197378 48.949516956994)
# 51006     POINT (-1.6836572418273 47.361339816463)
# 51007        POINT (3.5597374607055 49.5613321662)
# 51008    POINT (-0.58494064492909 44.839423842689)
# 51009    POINT (2.3429365361698 48.85661788762901)
# 51010      POINT (4.6407927051753 49.616142727886)
# 51011      POINT (4.1793920651404 43.993789824976)
# 51012    POINT (4.5427933362059 46.64478238347399)
# 51013       POINT (3.3684031318747 43.57940783738)
# 51014      POINT (4.1648162152356 45.727822272519)
# 51015      POINT (4.2387289197378 48.949516956994)
# 51016      POINT (3.8060645094517 45.128017097834)
# 51017      POINT (4.4256206829592 44.752769457921)
# 51018     POINT (-0.36283271663128 49.09974939647)
# 51019      POINT (4.6408685482117 45.871201034303)
# 51020       POINT (5.084387601353 43.545358259867)
# 51021      POINT (4.1793920651404 43.993789824976)
# 51022    POINT (5.167418223165201 44.685231158527)
# 51023      POINT (5.1771078692591 44.007106614213)
# 51024  POINT (-0.6576266691585799 48.147313244732)
# 51025      POINT (4.4256206829592 44.752769457921)
# 51026       POINT (5.225541776029 48.110462920584)
#
# [51027 rows x 23 columns]

# %%
# THEN EXECUTE THIS
city_codes = pd.read_csv('cities.csv', sep=';')


city_codes.rename(columns = {'geometry':'start_point', 'code_insee':'start_code_insee','polygon_id':'start_polygon_id'}, inplace = True) #',
city_codes = city_codes[['start_code_insee','start_polygon_id','start_point']]
city_codes.columns
# Out:
# Index(['start_code_insee', 'start_polygon_id', 'start_point'], dtype='object')

# %%
merge_attempt = pd.merge(merge_attempt, city_codes, how ='left', on='start_polygon_id')

# %% [markdown]
# What we have now is a dataframe with start and end polygons and movement related quantities. For each start and end polygon we have added the French departmental codes ('code_insee') through merge with city_codes.

# %%
merge_attempt.columns
# Out:
# Index(['geometry', 'date_time', 'start_polygon_id', 'start_polygon_name',
#        'end_polygon_id', 'end_polygon_name', 'length_km', 'tile_size',
#        'country', 'level', 'n_crisis', 'n_baseline', 'n_difference',
#        'percent_change', 'is_statistically_significant', 'z_score',
#        'start_lat', 'start_lon', 'end_lat', 'end_lon', 'date',
#        'end_code_insee', 'end_point', 'start_code_insee', 'start_point'],
#       dtype='object')

# %%
#merge_attempt.drop(['lieu'], axis= 1, inplace = True)#,'nuts3','wikipedia','surf_km2', 'feature_id']
#merge_attempt.rename(columns = {'geometry_x':'polygon_geometry','geometry_y':'insee_point'}, inplace = True) 
#merge_attempt.rename(columns = {'insee_point':'end_insee_point'}, inplace = True)

# %%
print (merge_attempt.shape)
print (merge_attempt.date_time.unique().shape) # We have three slices for each day (00:00-8:00, 8:00-16:00, 16:00-24:00)
print ('Number of unique origins',merge_attempt.start_polygon_name.unique().shape)
print ('Number of unique destinations', merge_attempt.end_polygon_name.unique().shape)
print ('Number of days', merge_attempt.date.unique().shape)
# Out:
# (51027, 25)
# (186,)
# Number of unique origins (94,)
# Number of unique destinations (94,)
# Number of days (62,)

# %%
# merge is successful, let us continue with movement data.
movement_data = merge_attempt

# %%
movement_data.to_csv('movements_with_insee_07-05-2020.csv')

# %%
print (movement_data.shape)
print (movement_data.date_time.unique().shape) # We have three slices for each day (00:00-8:00, 8:00-16:00, 16:00-24:00)
print ('Number of unique origins',movement_data.start_polygon_name.unique().shape)
print ('Number of unique destinations', movement_data.end_polygon_name.unique().shape)
print ('Number of days', movement_data.date.unique().shape)
# Out:
# (51027, 25)
# (186,)
# Number of unique origins (94,)
# Number of unique destinations (94,)
# Number of days (62,)

# %%
movement_data.head()
# Out:
#                                             geometry        date_time  \
# 0  LINESTRING (6.4072265625 47.54678262206, 6.372...  2020-04-13 1600
# 1  LINESTRING (-2.00390625 48.60962767452532, -2....  2020-04-13 1600
# 2  LINESTRING (6.702952665441177 48.4702643598611...  2020-04-13 1600
# 3  LINESTRING (6.7998046875 48.308484700771565, 6...  2020-04-13 1600
# 4  LINESTRING (6.801060267857143 43.5682258217796...  2020-04-13 1600
#
#    start_polygon_id  start_polygon_name  end_polygon_id    end_polygon_name  \
# 0            151058         Haute-Saône          151057               Doubs
# 1            162813     Ille-et-Vilaine          162816       Côtes-d'Armor
# 2            138785  Meurthe-et-Moselle          141764              Vosges
# 3            141764              Vosges          138785  Meurthe-et-Moselle
# 4            132360                 Var          132356     Alpes-Maritimes
#
#    length_km  tile_size country   level  ...  z_score  start_lat  start_lon  \
# 0  14.779808         12      FR  LEVEL3  ...     -4.0  47.641297   6.087378
# 1   7.262711         12      FR  LEVEL3  ...     -4.0  48.155998  -1.638757
# 2  13.670990         12      FR  LEVEL3  ...     -4.0  48.788773   6.161936
# 3  20.333646         12      FR  LEVEL3  ...     -4.0  48.196375   6.380097
# 4  11.988855         12      FR  LEVEL3  ...     -4.0  43.441394   6.244436
#
#      end_lat   end_lon        date  end_code_insee  \
# 0  47.165940  6.362767  2020-04-13              25
# 1  48.441082 -2.863818  2020-04-13              22
# 2  48.196375  6.380097  2020-04-13              88
# 3  48.788773  6.161936  2020-04-13              54
# 4  43.937499  7.116540  2020-04-13              06
#
#                                    end_point  start_code_insee  \
# 0      POINT (6.3627673495422 47.1659398827)                70
# 1   POINT (-2.8638179631241 48.441081670621)                35
# 2  POINT (6.380097025155799 48.196374688122)                54
# 3  POINT (6.161935534586201 48.788772923342)                88
# 4    POINT (7.1165396780881 43.937498635409)                83
#
#                                  start_point
# 0    POINT (6.0873779037648 47.641297246245)
# 1   POINT (-1.6387567734127 48.155998402337)
# 2  POINT (6.161935534586201 48.788772923342)
# 3  POINT (6.380097025155799 48.196374688122)
# 4    POINT (6.2444358836793 43.441394031236)
#
# [5 rows x 25 columns]

# %%
movement_data.columns
# Out:
# Index(['geometry', 'date_time', 'start_polygon_id', 'start_polygon_name',
#        'end_polygon_id', 'end_polygon_name', 'length_km', 'tile_size',
#        'country', 'level', 'n_crisis', 'n_baseline', 'n_difference',
#        'percent_change', 'is_statistically_significant', 'z_score',
#        'start_lat', 'start_lon', 'end_lat', 'end_lon', 'date',
#        'end_code_insee', 'end_point', 'start_code_insee', 'start_point'],
#       dtype='object')

# %%
(movement_data.shape[0] - movement_data[movement_data.end_code_insee == movement_data.start_code_insee].shape[0])/movement_data.shape[0]
# Out:
# 0.9927097419013463

# %% [markdown]
# # Population density data

# %% [markdown]
# Here are the explanations of the dataset and variables, as given by Facebook.
# DataSet Id: 1246339958888741
#
# Location density maps are heat maps, which show where people are located before, during and after a disaster and where populations have increased or decreased. We can compare this information to historical records, like population estimates based on satellite images. Comparing these data sets can help response organizations understand areas impacted by a natural disaster.
#
# The polygon/vector version of the daily location map displays the following metrics aggregated by administrative boundaries:
# * Date Time - The time period represented by the current map layer.
# * Standard (Z) Score - The number of standard deviations by which the crisis population count in the location differs from the baseline count.
# * Baseline:People - The average number of people we expect to be in the area during the specified time based on pre-disaster estimates.
# * Crisis:People - The number of people observed in the tile during the selected time period.
# * Difference - The difference between the population at the time of the crisis and the population during the baseline.
# * Percent Change - The percentage difference between the population at the time of the crisis and the population during the baseline.

# %% [markdown]
# Let us check population density data and see what can be added to the previous data structure to enrich it.

# %%
path = 'administrative_density/'
filenames = listdir(path)

# %%
# build a list of dataframes
frames = [ build_frames(f, path) for f in filenames ]
# concat dataframes (we can sort data later cause all dfs are timestamped)
population_density_data = pd.concat(frames)

# %%
population_density_data['date'] = [row.date() for row in pd.to_datetime(population_density_data.date_time)]

# %%
population_density_data = population_density_data[population_density_data['country'] == 'FR']

# %%
population_density_data.columns
# Out:
# Index(['spaco_id', 'country', 'polygon_name', 'level', 'date_time',
#        'n_baseline', 'n_crisis', 'density_baseline', 'density_crisis',
#        'n_difference', 'percent_change', 'clipped_z_score', 'lat', 'lon',
#        'date'],
#       dtype='object')

# %%
population_density_data.polygon_name.unique().shape
# Out:
# (94,)

# %% [markdown]
# This dataset contains population density information. We will transfer some of this information to the movement_data we built above. We shall change columns names two times to be able to merge both on start and end polygons, so that density information for both start and end polygons of movement_data appears on that dataframe.

# %%
end_pop = population_density_data[['date_time', 'polygon_name','n_crisis','n_baseline','percent_change']]
end_pop.columns = ['date_time', 'end_polygon_name','end_density_crisis','end_density_baseline','end_density_percent_change']
end_pop.shape
# Out:
# (17484, 5)

# %%
start_pop = population_density_data[['date_time', 'polygon_name','n_crisis','n_baseline','percent_change']]
start_pop.columns = ['date_time', 'start_polygon_name','start_density_crisis','start_density_baseline','start_density_percent_change']
start_pop.shape
# Out:
# (17484, 5)

# %%
density_merge_attempt = pd.merge(movement_data,end_pop,how='left', on=['end_polygon_name','date_time'])

# %%
density_merge_attempt = pd.merge(density_merge_attempt,start_pop,how='left', on=['start_polygon_name','date_time'])

# %%
density_merge_attempt.shape
# Out:
# (51027, 31)

# %%
density_merge_attempt.columns
# Out:
# Index(['geometry', 'date_time', 'start_polygon_id', 'start_polygon_name',
#        'end_polygon_id', 'end_polygon_name', 'length_km', 'tile_size',
#        'country', 'level', 'n_crisis', 'n_baseline', 'n_difference',
#        'percent_change', 'is_statistically_significant', 'z_score',
#        'start_lat', 'start_lon', 'end_lat', 'end_lon', 'date',
#        'end_code_insee', 'end_point', 'start_code_insee', 'start_point',
#        'end_density_crisis', 'end_density_baseline',
#        'end_density_percent_change', 'start_density_crisis',
#        'start_density_baseline', 'start_density_percent_change'],
#       dtype='object')

# %%
density_merge_attempt.to_csv('movement_with_density_code_insee_07-05-2020.csv')
