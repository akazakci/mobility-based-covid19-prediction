# %% [markdown]
# # Regression

# %% [markdown]
# _Akin Kazakci, MINES ParisTech, PSL University_

# %%
import pandas as pd
import numpy as np
from numpy import loadtxt
from numpy import sort

import seaborn as sns
import matplotlib.pyplot as plt
import os

from sklearn.datasets import load_boston
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LassoCV
from sklearn.model_selection import TimeSeriesSplit
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
import warnings
warnings.filterwarnings('ignore')
import pickle

sns.set(style="white")

# %% [markdown]
# **Following are utility functions (mainly data preparation & feature generation). Scroll down to models & experiments for regression.**

# %%
def data_prep(columns_to_keep, cols_to_lag = None, incid_lag = False, incid_lag_start = 7, incid_lag_end = 1,
              col_lag_start = 21, col_lag_end = 14):
    # get influx data, regroup by department and date
    influx = pd.read_csv('influx_to_dept_by_date.csv', index_col = 0)
    influx = influx.groupby(['code_insee','date'], as_index = False).agg(
        {
            'movement':'sum',
            'length_km':'sum',
            'movement_baseline':'sum', 
            'movement_difference':'sum',
            'movement_percent_change':'sum', 
            'density_weighted_movement':'sum'

        }
    )
    #get incidence data
    incid = pd.read_csv('incidence.csv', index_col = 0)
    
    #get graph stats data
    stat = pd.read_csv('graph_stats_dept_by_date.csv',index_col = 0)
    
    #merge
    incid = pd.merge(incid, stat, how='left', on = ['code_insee','date'])
    data = pd.merge(incid, influx, how='left', on = ['code_insee','date'])
    
    #print ('cols after merge',data.columns)
    #drop non target columns
    data = data.drop(['incid_rea', 'incid_dc', 'incid_rad',
           'c_incidence', 'c_reanim', 'c_deces', 'c_rad'], axis = 1)
    #print(data.columns)
    #sort by date
    data = data.sort_values('date')
    
    # only keep columns specified for this experiment 
    #(assumes we have 'date','code_insee', 'date_time', 'time' in columns)
    # those are droppd by split_for_test later on
    data = data[columns_to_keep]
    
    # add or not, autoregressive variables on target
    if incid_lag:
        data = prep_lags(data, 'code_insee', ['incid_hosp'],incid_lag_start, incid_lag_end)
        #lags = range(incid_lag_end,incid_lag_start)
        #co = ['incid_hosp']
        #data.assign(**{
        #    '{} (t-{})'.format(col, t): data.groupby('code_insee')[col].shift(t)
        #    for t in lags
        #    for col in co
        #})
        #print('after incid', data.columns)
        # drop rows with NaNs
        data = data.dropna()
      
    else:
        pass
    
    if cols_to_lag is None:
        pass
    else:
        data = prep_lags(data,'code_insee', cols_to_lag, col_lag_start, col_lag_end )
        
    return data

# %%
def prep_lags(data, key, cols, lag_start, lag_end):
    lags = range(lag_end,lag_start+1)
    
    data = data.sort_values('date')
    #print('prep_lags sort',data.columns)
    # OLD CODE, DO NOT USE
    #data = data.assign(**{
    #    '{} (t-{})'.format(col, t): modified_shift(data, 'code_insee', col, t)
    #    for t in lags
    #    for col in cols
    #})
    for c in cols:
        for lag in lags:
            #print('c',c,'lag',lag)
            data = modified_shift(data, key, c, lag)
            #print(c, lag, data.columns)
    
    
    # drop rows with NaNs
    data = data.dropna()
    # drop original columns that are now lagged
    if cols != ['incid_hosp']:
        data = data.drop(cols, axis =1)
    #for c in data.columns:
        #print(c)
    
    return data

# %%
def modified_shift(data, key, c, lag):

   # data.assign(**{
   #     '{} (t-{})'.format(col, lag): data.groupby('key')[col].shift(lag)
   # })
    duc = data.groupby(key)[c].shift(lag)
    duc.rename(str(c)+ '(t-'+str(lag)+')', inplace = True)
   
    #print('duc',duc.head(2))
    data = pd.concat([
        data,
        duc
    ], axis=1)
    return data

# %%
#OLD, DO _NOT_ USE
def data_shift(dat, cols, lag):
    
    #plain old shift, for specified columns and lag
    #this needs to be changed if I want to have several shifts for same variables
    dat[cols] = dat[cols].shift(lag)
    dat = dat.dropna()    
    return dat

# %%
def split_for_test(data, split_date):
   
    dataset = data.sort_values('date')
    #print('split_for_test sort',dataset.columns)
    train, val = dataset[dataset.date <= split_date], dataset[dataset.date > split_date]
    train_with_codes, val_with_codes = train, val 
    # once the split for the split_date has been made, I can drop date
    # but also all the other columns the predictor won't take into account
    train.drop(['date','code_insee'], inplace = True, axis = 1)
    val.drop(['date','code_insee'], inplace  = True, axis =1)
    
    return train, val, train_with_codes, val_with_codes

# %%
def expe(model_name, columns_to_keep, cols_to_lag, incid_lag = False, incid_lag_start = 7, incid_lag_end = 1,
              col_lag_start = 21, col_lag_end = 14, depth = 3):
    
    data = data_prep(columns_to_keep, cols_to_lag, incid_lag , incid_lag_start, incid_lag_end ,
              col_lag_start, col_lag_end)
    
    #print(data.columns)
    #if you want to change features do here  
    #data['incid_hosp'] = np.exp(data['incid_hosp'])
   
    
    train, val, train_w_c, val_w_c = split_for_test(data,split_date = '2020-04-20' )
    #print(train.columns)

    #split data into X and y
    X_train, y_train = train.drop('incid_hosp', axis = 1), train['incid_hosp']
    X_test, y_test = val.drop('incid_hosp', axis = 1), val['incid_hosp']

    # split data into train and test sets
    tscv = TimeSeriesSplit(10)

    # fit model on all training data
    model =  XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
             colsample_bynode=1, colsample_bytree=1, eval_metric='mae',
             gamma=0.5, importance_type='gain', learning_rate=0.03,
             max_delta_step=0, max_depth=3, min_child_weight=1, 
             n_estimators=1000, n_jobs=-1, nthread=None, objective='count:poisson',
             random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
             seed=None, silent=True, subsample=1.0, verbosity=1, cv = tscv)
    model.fit(X_train, y_train)

    # make predictions for test data and evaluate
    predictions = model.predict(X_test)
    MAE = mean_absolute_error(y_test, predictions)
    
    # print score and other params
    if cols_to_lag is None:
        print("MAE: %.2f" % (MAE), 'train shape: ',train.shape)
    else:
        print("MAE: %.2f" % (MAE), 'train shape: ',train.shape, 'mov window: ',col_lag_start, col_lag_end )

    # get important features
    importances = (model.feature_importances_)
    selection = SelectFromModel(model, prefit=True)
    if model_name is not None:
        path = 'models/'
        data_path = 'data/expe_data'
        pickle.dump(model, open(os.path.join(path,model_name), "wb"))
        data.to_csv(os.path.join(data_path,'data_for_'+model_name+'.csv'))
        val_w_c.to_csv(os.path.join(data_path,'test_data_for_'+model_name+'.csv'))
      
    params = selection.get_params()

    support = selection.get_support()
    features = X_train.columns[support]

    #alternative dico for score charting

    dico = {'columns_to_keep':columns_to_keep,
            'cols_to_lag': cols_to_lag,
            'incid_lag': incid_lag,
            'incid_lag_start':incid_lag_start,
            'incid_lag_end':incid_lag_end ,
            'col_lag_start':col_lag_start , 
            'col_lag_end':col_lag_end , 
            'depth':depth , 
            'MAE':MAE,
            'features':features,
            'model_input_cols':X_train.columns,
            'model_parameters': params,
            'model_name':model_name}
    return dico

# %% [markdown]
# # Models & Experiments

# %%
#will keep results of experiments here:
results = []

# %% [markdown]
# ## Baseline

# %% [markdown]
# The baseline only takes autoregressive varibles into account. Other specified parameters are not taken into account.

# %%
cols = ['incid_hosp', 'date','code_insee'] # just the target column but with incid_past = True on expe(), so we have 6 days of history
cols_to_lag = None

dico = expe('exp_diff_baseline_auto_incid_7_mob14-21.pickle', cols, cols_to_lag ,incid_lag = True, incid_lag_start = 7,
            incid_lag_end = 1, col_lag_start = 21, col_lag_end = 14)
#print(dico)
results.append(dico)
# Out:
# MAE: 5.29 train shape:  (2626, 8)

# %% [markdown]
# Without much optimisation (simple trees, max_dept = 5, no grid search, etc), we have MAE between around 5 to 6. To give some perspective, this means ~500-600 errors per day, as we will predict on ~100 departments.

# %%
# change depth for auto-regressive features; score improves with more history, even though samples diminish
cols = ['incid_hosp', 'date','code_insee'] # just the target column but with incid_past = True on expe(), so we have 6 days of history
cols_to_lag = None

for i in range(2,25):
    dico = expe(None, cols, cols_to_lag ,incid_lag = True, incid_lag_start = i,
                incid_lag_end = 1, col_lag_start = 21, col_lag_end = 14)
#print(dico)
    results.append(dico)
# Out:
# MAE: 5.74 train shape:  (3131, 3)
# MAE: 5.69 train shape:  (3030, 4)
# MAE: 5.59 train shape:  (2929, 5)
# MAE: 5.54 train shape:  (2828, 6)
# MAE: 5.48 train shape:  (2727, 7)
# MAE: 5.27 train shape:  (2626, 8)
# MAE: 5.19 train shape:  (2525, 9)
# MAE: 5.19 train shape:  (2424, 10)
# MAE: 5.09 train shape:  (2323, 11)
# MAE: 5.14 train shape:  (2222, 12)
# MAE: 5.12 train shape:  (2121, 13)
# MAE: 5.05 train shape:  (2020, 14)
# MAE: 4.99 train shape:  (1919, 15)
# MAE: 4.92 train shape:  (1818, 16)
# MAE: 5.05 train shape:  (1717, 17)
# MAE: 5.00 train shape:  (1616, 18)
# MAE: 5.02 train shape:  (1515, 19)
# MAE: 5.01 train shape:  (1414, 20)
# MAE: 4.89 train shape:  (1313, 21)
# MAE: 4.97 train shape:  (1212, 22)
# MAE: 4.94 train shape:  (1111, 23)
# MAE: 5.21 train shape:  (1010, 24)
# MAE: 4.91 train shape:  (909, 25)

# %% [markdown]
# # Auto-regressive features with movement features

# %% [markdown]
# A critical point is the selection of the time window where we shall get the movement features from. Given the 5-6 days incubation time for Covid-19, and 10-14 days before patients go to hospitals (all of these statistics should be checked), a window of -21 to -14 days seems reasonable to include in the model.

# %% [markdown]
# However, as the size of the windows increases the number of (lag) features multiply quickly, hence, the performance of the estimator decrease.

# %% [markdown]
# 10-9 and 12-10 seems to be good windows for movement features. But the choice is tricky because of the window size issue. For ex, for 21-14 the MAE is 7.56 with train shape (313, 62). For 10-9, MAE is 6.4 with only 26 columns. (In all these models we have xgboost trees of depth 3, 1000 estimators and col_sample=0.1)

# %% [markdown]
# Still, the 10-9 window seems like a workable solution given the error rate and the objective of having a 'good enoughsimulator using movement data'

# %%
cols = ['incid_hosp', 
       'length_km', 'movement', 'movement_baseline', 'movement_difference',
       'movement_percent_change', 'density_weighted_movement','date','code_insee']

cols_to_lag = ['length_km', 'movement', 'movement_baseline', 'movement_difference',
       'movement_percent_change', 'density_weighted_movement']

for i in range(10,22):
    for j in range(1, 8):
        #print(i,j)
        dico = expe('auto_mov_incid_7_mob{}-{}.pickle'.format(i-j,i),cols, cols_to_lag ,incid_lag = True, incid_lag_start = 7,
            incid_lag_end = 1, col_lag_start = i, col_lag_end = i-j)
    
results.append(dico)
# Out:
# MAE: 6.05 train shape:  (1242, 20) mov window:  10 9
# MAE: 6.21 train shape:  (1242, 26) mov window:  10 8
# MAE: 6.32 train shape:  (1242, 32) mov window:  10 7
# MAE: 6.35 train shape:  (1242, 38) mov window:  10 6
# MAE: 6.27 train shape:  (1242, 44) mov window:  10 5
# MAE: 6.30 train shape:  (1242, 50) mov window:  10 4
# MAE: 6.72 train shape:  (1242, 56) mov window:  10 3
# MAE: 6.15 train shape:  (1154, 20) mov window:  11 10
# MAE: 6.19 train shape:  (1154, 26) mov window:  11 9
# MAE: 6.17 train shape:  (1154, 32) mov window:  11 8
# MAE: 6.19 train shape:  (1154, 38) mov window:  11 7
# MAE: 6.11 train shape:  (1154, 44) mov window:  11 6
# MAE: 6.11 train shape:  (1154, 50) mov window:  11 5
# MAE: 6.23 train shape:  (1154, 56) mov window:  11 4
# MAE: 6.17 train shape:  (1067, 20) mov window:  12 11
# MAE: 6.27 train shape:  (1067, 26) mov window:  12 10
# MAE: 6.24 train shape:  (1067, 32) mov window:  12 9
# MAE: 6.34 train shape:  (1067, 38) mov window:  12 8
# MAE: 6.38 train shape:  (1067, 44) mov window:  12 7
# MAE: 6.49 train shape:  (1067, 50) mov window:  12 6
# MAE: 6.58 train shape:  (1067, 56) mov window:  12 5
# MAE: 6.14 train shape:  (980, 20) mov window:  13 12
# MAE: 6.24 train shape:  (980, 26) mov window:  13 11
# MAE: 6.20 train shape:  (980, 32) mov window:  13 10
# MAE: 6.36 train shape:  (980, 38) mov window:  13 9
# MAE: 6.47 train shape:  (980, 44) mov window:  13 8
# MAE: 6.52 train shape:  (980, 50) mov window:  13 7
# MAE: 6.51 train shape:  (980, 56) mov window:  13 6
# MAE: 6.66 train shape:  (894, 20) mov window:  14 13
# MAE: 6.62 train shape:  (894, 26) mov window:  14 12
# MAE: 6.39 train shape:  (894, 32) mov window:  14 11
# MAE: 6.50 train shape:  (894, 38) mov window:  14 10
# MAE: 6.77 train shape:  (894, 44) mov window:  14 9
# MAE: 6.85 train shape:  (894, 50) mov window:  14 8
# MAE: 6.71 train shape:  (894, 56) mov window:  14 7
# MAE: 6.93 train shape:  (808, 20) mov window:  15 14
# MAE: 6.92 train shape:  (808, 26) mov window:  15 13
# MAE: 6.74 train shape:  (808, 32) mov window:  15 12
# MAE: 6.71 train shape:  (808, 38) mov window:  15 11
# MAE: 6.71 train shape:  (808, 44) mov window:  15 10
# MAE: 6.66 train shape:  (808, 50) mov window:  15 9
# MAE: 6.61 train shape:  (808, 56) mov window:  15 8
# MAE: 6.44 train shape:  (722, 20) mov window:  16 15
# MAE: 6.62 train shape:  (722, 26) mov window:  16 14
# MAE: 6.87 train shape:  (722, 32) mov window:  16 13
# MAE: 6.68 train shape:  (722, 38) mov window:  16 12
# MAE: 6.68 train shape:  (722, 44) mov window:  16 11
# MAE: 6.72 train shape:  (722, 50) mov window:  16 10
# MAE: 6.61 train shape:  (722, 56) mov window:  16 9
# MAE: 6.71 train shape:  (636, 20) mov window:  17 16
# MAE: 6.62 train shape:  (636, 26) mov window:  17 15
# MAE: 7.18 train shape:  (636, 32) mov window:  17 14
# MAE: 7.09 train shape:  (636, 38) mov window:  17 13
# MAE: 7.09 train shape:  (636, 44) mov window:  17 12
# MAE: 7.11 train shape:  (636, 50) mov window:  17 11
# MAE: 7.12 train shape:  (636, 56) mov window:  17 10
# MAE: 7.09 train shape:  (551, 20) mov window:  18 17
# MAE: 7.11 train shape:  (551, 26) mov window:  18 16
# MAE: 7.10 train shape:  (551, 32) mov window:  18 15
# MAE: 7.66 train shape:  (551, 38) mov window:  18 14
# MAE: 7.52 train shape:  (551, 44) mov window:  18 13
# MAE: 7.64 train shape:  (551, 50) mov window:  18 12
# MAE: 7.66 train shape:  (551, 56) mov window:  18 11
# MAE: 6.38 train shape:  (467, 20) mov window:  19 18
# MAE: 7.11 train shape:  (467, 26) mov window:  19 17
# MAE: 6.99 train shape:  (467, 32) mov window:  19 16
# MAE: 7.23 train shape:  (467, 38) mov window:  19 15
# MAE: 7.64 train shape:  (467, 44) mov window:  19 14
# MAE: 7.47 train shape:  (467, 50) mov window:  19 13
# MAE: 7.53 train shape:  (467, 56) mov window:  19 12
# MAE: 6.78 train shape:  (387, 20) mov window:  20 19
# MAE: 6.89 train shape:  (387, 26) mov window:  20 18
# MAE: 6.88 train shape:  (387, 32) mov window:  20 17
# MAE: 6.83 train shape:  (387, 38) mov window:  20 16
# MAE: 7.25 train shape:  (387, 44) mov window:  20 15
# MAE: 7.52 train shape:  (387, 50) mov window:  20 14
# MAE: 7.36 train shape:  (387, 56) mov window:  20 13
# MAE: 6.91 train shape:  (313, 20) mov window:  21 20
# MAE: 6.93 train shape:  (313, 26) mov window:  21 19
# MAE: 6.87 train shape:  (313, 32) mov window:  21 18
# MAE: 6.91 train shape:  (313, 38) mov window:  21 17
# MAE: 6.90 train shape:  (313, 44) mov window:  21 16
# MAE: 7.07 train shape:  (313, 50) mov window:  21 15
# MAE: 7.24 train shape:  (313, 56) mov window:  21 14

# %% [markdown]
# # Graph, movement and auto-regressive features

# %% [markdown]
# Would the graph features we built would improve the scores? Note that again, 12-10 gives the best score. Also, 19-17 is a close by. This might be due to a "weekly cycle" effect.

# %%
cols = ['incid_hosp', 
       'betweenness_centrality-16_0', 'closeness_centrality-16_0',
       'degree_centrality-16_0', 'eigenvector_centrality-16_0',
       'betweenness_centrality-0_8', 'closeness_centrality-0_8',
       'degree_centrality-0_8', 'eigenvector_centrality-0_8',
       'betweenness_centrality-8_16', 'closeness_centrality-8_16',
       'degree_centrality-8_16', 'eigenvector_centrality-8_16', 
       'length_km', 'movement', 'movement_baseline', 'movement_difference',
       'movement_percent_change', 'density_weighted_movement','date','code_insee']

cols_to_lag = ['betweenness_centrality-16_0', 'closeness_centrality-16_0',
               'degree_centrality-16_0', 'eigenvector_centrality-16_0',
               'betweenness_centrality-0_8', 'closeness_centrality-0_8',
               'degree_centrality-0_8', 'eigenvector_centrality-0_8',
               'betweenness_centrality-8_16', 'closeness_centrality-8_16',
               'degree_centrality-8_16', 'eigenvector_centrality-8_16','length_km', 'movement', 'movement_baseline', 'movement_difference',
       'movement_percent_change', 'density_weighted_movement',]

for i in range(10,22):
    for j in range(1, 8):
        dico = expe('obj_count_auto_mov_gr_incid_7_mob{}-{}.pickle'.format(i-j,i),cols, cols_to_lag ,incid_lag = True, incid_lag_start = 7,
            incid_lag_end = 1, col_lag_start = i, col_lag_end = i-j)
    
        results.append(dico)
# Out:
# MAE: 6.70 train shape:  (1026, 44) mov window:  10 9
# MAE: 6.68 train shape:  (1026, 62) mov window:  10 8
# MAE: 8.14 train shape:  (1026, 80) mov window:  10 7
# MAE: 8.13 train shape:  (1026, 98) mov window:  10 6
# MAE: 8.01 train shape:  (1026, 116) mov window:  10 5
# MAE: 8.09 train shape:  (1026, 134) mov window:  10 4
# MAE: 8.06 train shape:  (1026, 152) mov window:  10 3
# MAE: 6.75 train shape:  (944, 44) mov window:  11 10
# MAE: 6.99 train shape:  (944, 62) mov window:  11 9
# MAE: 7.20 train shape:  (944, 80) mov window:  11 8
# MAE: 8.51 train shape:  (944, 98) mov window:  11 7
# MAE: 10.93 train shape:  (944, 116) mov window:  11 6
# MAE: 10.87 train shape:  (944, 134) mov window:  11 5
# MAE: 11.08 train shape:  (944, 152) mov window:  11 4
# MAE: 6.72 train shape:  (864, 44) mov window:  12 11
# MAE: 6.72 train shape:  (864, 62) mov window:  12 10
# MAE: 6.59 train shape:  (864, 80) mov window:  12 9
# MAE: 8.12 train shape:  (864, 98) mov window:  12 8
# MAE: 8.30 train shape:  (864, 116) mov window:  12 7
# MAE: 8.03 train shape:  (864, 134) mov window:  12 6
# MAE: 8.10 train shape:  (864, 152) mov window:  12 5
# MAE: 9.79 train shape:  (787, 44) mov window:  13 12
# MAE: 9.75 train shape:  (787, 62) mov window:  13 11
# MAE: 11.80 train shape:  (787, 80) mov window:  13 10
# MAE: 14.04 train shape:  (787, 98) mov window:  13 9
# MAE: 8.67 train shape:  (787, 116) mov window:  13 8
# MAE: 9.14 train shape:  (787, 134) mov window:  13 7
# MAE: 8.87 train shape:  (787, 152) mov window:  13 6
# MAE: 8.04 train shape:  (712, 44) mov window:  14 13
# MAE: 7.58 train shape:  (712, 62) mov window:  14 12
# MAE: 7.60 train shape:  (712, 80) mov window:  14 11
# MAE: 7.59 train shape:  (712, 98) mov window:  14 10
# MAE: 8.00 train shape:  (712, 116) mov window:  14 9
# MAE: 8.02 train shape:  (712, 134) mov window:  14 8
# MAE: 8.45 train shape:  (712, 152) mov window:  14 7
# MAE: 8.23 train shape:  (637, 44) mov window:  15 14
# MAE: 8.42 train shape:  (637, 62) mov window:  15 13
# MAE: 7.80 train shape:  (637, 80) mov window:  15 12
# MAE: 7.73 train shape:  (637, 98) mov window:  15 11
# MAE: 7.74 train shape:  (637, 116) mov window:  15 10
# MAE: 7.85 train shape:  (637, 134) mov window:  15 9
# MAE: 7.88 train shape:  (637, 152) mov window:  15 8
# MAE: 8.13 train shape:  (563, 44) mov window:  16 15
# MAE: 8.33 train shape:  (563, 62) mov window:  16 14
# MAE: 8.36 train shape:  (563, 80) mov window:  16 13
# MAE: 8.14 train shape:  (563, 98) mov window:  16 12
# MAE: 8.24 train shape:  (563, 116) mov window:  16 11
# MAE: 8.22 train shape:  (563, 134) mov window:  16 10
# MAE: 8.25 train shape:  (563, 152) mov window:  16 9
# MAE: 7.55 train shape:  (489, 44) mov window:  17 16
# MAE: 8.72 train shape:  (489, 62) mov window:  17 15
# MAE: 9.77 train shape:  (489, 80) mov window:  17 14
# MAE: 9.33 train shape:  (489, 98) mov window:  17 13
# MAE: 9.27 train shape:  (489, 116) mov window:  17 12
# MAE: 9.03 train shape:  (489, 134) mov window:  17 11
# MAE: 9.16 train shape:  (489, 152) mov window:  17 10
# MAE: 7.73 train shape:  (418, 44) mov window:  18 17
# MAE: 14.01 train shape:  (418, 62) mov window:  18 16
# MAE: 9.23 train shape:  (418, 80) mov window:  18 15
# MAE: 9.22 train shape:  (418, 98) mov window:  18 14
# MAE: 9.15 train shape:  (418, 116) mov window:  18 13
# MAE: 9.11 train shape:  (418, 134) mov window:  18 12
# MAE: 8.80 train shape:  (418, 152) mov window:  18 11
# MAE: 7.97 train shape:  (351, 44) mov window:  19 18
# MAE: 7.99 train shape:  (351, 62) mov window:  19 17
# MAE: 8.06 train shape:  (351, 80) mov window:  19 16
# MAE: 8.18 train shape:  (351, 98) mov window:  19 15
# MAE: 9.03 train shape:  (351, 116) mov window:  19 14
# MAE: 9.25 train shape:  (351, 134) mov window:  19 13
# MAE: 9.04 train shape:  (351, 152) mov window:  19 12
# MAE: 7.65 train shape:  (288, 44) mov window:  20 19
# MAE: 7.96 train shape:  (288, 62) mov window:  20 18
# MAE: 8.06 train shape:  (288, 80) mov window:  20 17
# MAE: 7.82 train shape:  (288, 98) mov window:  20 16
# MAE: 7.95 train shape:  (288, 116) mov window:  20 15
# MAE: 10.86 train shape:  (288, 134) mov window:  20 14
# MAE: 10.89 train shape:  (288, 152) mov window:  20 13
# MAE: 8.21 train shape:  (231, 44) mov window:  21 20
# MAE: 8.05 train shape:  (231, 62) mov window:  21 19
# MAE: 8.14 train shape:  (231, 80) mov window:  21 18
# MAE: 8.11 train shape:  (231, 98) mov window:  21 17
# MAE: 8.49 train shape:  (231, 116) mov window:  21 16
# MAE: 8.20 train shape:  (231, 134) mov window:  21 15
# MAE: 8.29 train shape:  (231, 152) mov window:  21 14

# %% [markdown]
# ## Autoregressive features with graph features

# %% [markdown]
# This time without original movement features, but only graph based features we built. On average, the results are slightly better than when we also have movement features. This might be due to the 'number of columns' issue mentioned. Nevertheless, graph features seems to be useful.

# %%
cols = ['incid_hosp','betweenness_centrality-16_0', 'closeness_centrality-16_0',
               'degree_centrality-16_0', 'eigenvector_centrality-16_0',
               'betweenness_centrality-0_8', 'closeness_centrality-0_8',
               'degree_centrality-0_8', 'eigenvector_centrality-0_8',
               'betweenness_centrality-8_16', 'closeness_centrality-8_16',
               'degree_centrality-8_16', 'eigenvector_centrality-8_16', 'date','code_insee'
       ]



cols_to_lag = ['betweenness_centrality-16_0', 'closeness_centrality-16_0',
               'degree_centrality-16_0', 'eigenvector_centrality-16_0',
               'betweenness_centrality-0_8', 'closeness_centrality-0_8',
               'degree_centrality-0_8', 'eigenvector_centrality-0_8',
               'betweenness_centrality-8_16', 'closeness_centrality-8_16',
               'degree_centrality-8_16', 'eigenvector_centrality-8_16']

for i in range(10,22):
    for j in range(1, 8):
        dico = expe('auto_gr_incid_7_mob{}-{}.pickle'.format(i-j,i),cols, cols_to_lag ,incid_lag = True, incid_lag_start = 7,
            incid_lag_end = 1, col_lag_start = i, col_lag_end = i-j)
        results.append(dico)
#results
# Out:
# MAE: 6.38 train shape:  (1026, 32) mov window:  10 9
# MAE: 6.74 train shape:  (1026, 44) mov window:  10 8
# MAE: 7.14 train shape:  (1026, 56) mov window:  10 7
# MAE: 7.10 train shape:  (1026, 68) mov window:  10 6
# MAE: 7.32 train shape:  (1026, 80) mov window:  10 5
# MAE: 7.69 train shape:  (1026, 92) mov window:  10 4
# MAE: 7.84 train shape:  (1026, 104) mov window:  10 3
# MAE: 6.30 train shape:  (944, 32) mov window:  11 10
# MAE: 6.29 train shape:  (944, 44) mov window:  11 9
# MAE: 6.86 train shape:  (944, 56) mov window:  11 8
# MAE: 7.04 train shape:  (944, 68) mov window:  11 7
# MAE: 6.96 train shape:  (944, 80) mov window:  11 6
# MAE: 6.99 train shape:  (944, 92) mov window:  11 5
# MAE: 7.64 train shape:  (944, 104) mov window:  11 4
# MAE: 6.51 train shape:  (864, 32) mov window:  12 11
# MAE: 6.54 train shape:  (864, 44) mov window:  12 10
# MAE: 6.60 train shape:  (864, 56) mov window:  12 9
# MAE: 6.88 train shape:  (864, 68) mov window:  12 8
# MAE: 7.07 train shape:  (864, 80) mov window:  12 7
# MAE: 7.04 train shape:  (864, 92) mov window:  12 6
# MAE: 7.33 train shape:  (864, 104) mov window:  12 5
# MAE: 7.04 train shape:  (787, 32) mov window:  13 12
# MAE: 6.90 train shape:  (787, 44) mov window:  13 11
# MAE: 6.60 train shape:  (787, 56) mov window:  13 10
# MAE: 6.69 train shape:  (787, 68) mov window:  13 9
# MAE: 6.80 train shape:  (787, 80) mov window:  13 8
# MAE: 7.11 train shape:  (787, 92) mov window:  13 7
# MAE: 7.02 train shape:  (787, 104) mov window:  13 6
# MAE: 6.73 train shape:  (712, 32) mov window:  14 13
# MAE: 6.78 train shape:  (712, 44) mov window:  14 12
# MAE: 6.72 train shape:  (712, 56) mov window:  14 11
# MAE: 6.68 train shape:  (712, 68) mov window:  14 10
# MAE: 6.63 train shape:  (712, 80) mov window:  14 9
# MAE: 6.80 train shape:  (712, 92) mov window:  14 8
# MAE: 6.90 train shape:  (712, 104) mov window:  14 7
# MAE: 6.98 train shape:  (637, 32) mov window:  15 14
# MAE: 6.99 train shape:  (637, 44) mov window:  15 13
# MAE: 6.96 train shape:  (637, 56) mov window:  15 12
# MAE: 6.92 train shape:  (637, 68) mov window:  15 11
# MAE: 6.78 train shape:  (637, 80) mov window:  15 10
# MAE: 6.86 train shape:  (637, 92) mov window:  15 9
# MAE: 7.12 train shape:  (637, 104) mov window:  15 8
# MAE: 7.03 train shape:  (563, 32) mov window:  16 15
# MAE: 7.06 train shape:  (563, 44) mov window:  16 14
# MAE: 7.30 train shape:  (563, 56) mov window:  16 13
# MAE: 6.99 train shape:  (563, 68) mov window:  16 12
# MAE: 7.13 train shape:  (563, 80) mov window:  16 11
# MAE: 6.91 train shape:  (563, 92) mov window:  16 10
# MAE: 6.89 train shape:  (563, 104) mov window:  16 9
# MAE: 7.53 train shape:  (489, 32) mov window:  17 16
# MAE: 7.86 train shape:  (489, 44) mov window:  17 15
# MAE: 7.82 train shape:  (489, 56) mov window:  17 14
# MAE: 7.93 train shape:  (489, 68) mov window:  17 13
# MAE: 7.37 train shape:  (489, 80) mov window:  17 12
# MAE: 7.29 train shape:  (489, 92) mov window:  17 11
# MAE: 7.27 train shape:  (489, 104) mov window:  17 10
# MAE: 7.08 train shape:  (418, 32) mov window:  18 17
# MAE: 7.90 train shape:  (418, 44) mov window:  18 16
# MAE: 7.65 train shape:  (418, 56) mov window:  18 15
# MAE: 7.87 train shape:  (418, 68) mov window:  18 14
# MAE: 8.11 train shape:  (418, 80) mov window:  18 13
# MAE: 7.63 train shape:  (418, 92) mov window:  18 12
# MAE: 7.45 train shape:  (418, 104) mov window:  18 11
# MAE: 7.67 train shape:  (351, 32) mov window:  19 18
# MAE: 7.38 train shape:  (351, 44) mov window:  19 17
# MAE: 8.09 train shape:  (351, 56) mov window:  19 16
# MAE: 8.46 train shape:  (351, 68) mov window:  19 15
# MAE: 8.10 train shape:  (351, 80) mov window:  19 14
# MAE: 8.00 train shape:  (351, 92) mov window:  19 13
# MAE: 8.20 train shape:  (351, 104) mov window:  19 12
# MAE: 7.73 train shape:  (288, 32) mov window:  20 19
# MAE: 7.40 train shape:  (288, 44) mov window:  20 18
# MAE: 7.73 train shape:  (288, 56) mov window:  20 17
# MAE: 8.14 train shape:  (288, 68) mov window:  20 16
# MAE: 8.64 train shape:  (288, 80) mov window:  20 15
# MAE: 8.01 train shape:  (288, 92) mov window:  20 14
# MAE: 7.98 train shape:  (288, 104) mov window:  20 13
# MAE: 8.10 train shape:  (231, 32) mov window:  21 20
# MAE: 7.97 train shape:  (231, 44) mov window:  21 19
# MAE: 7.79 train shape:  (231, 56) mov window:  21 18
# MAE: 9.44 train shape:  (231, 68) mov window:  21 17
# MAE: 9.35 train shape:  (231, 80) mov window:  21 16
# MAE: 9.74 train shape:  (231, 92) mov window:  21 15
# MAE: 8.91 train shape:  (231, 104) mov window:  21 14

# %%
results
# Out:
# [{'columns_to_keep': ['incid_hosp', 'date', 'code_insee'],
#   'cols_to_lag': None,
#   'incid_lag': True,
#   'incid_lag_start': 7,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 14,
#   'depth': 3,
#   'MAE': 5.272442127734718,
#   'features': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)'], dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#                 subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': 'baseline_auto_incid_7_mob14-21.pickle'},
#  {'columns_to_keep': ['incid_hosp', 'date', 'code_insee'],
#   'cols_to_lag': None,
#   'incid_lag': True,
#   'incid_lag_start': 2,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 14,
#   'depth': 3,
#   'MAE': 5.744070166703498,
#   'features': Index(['incid_hosp(t-1)'], dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)'], dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#                 subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': None},
#  {'columns_to_keep': ['incid_hosp', 'date', 'code_insee'],
#   'cols_to_lag': None,
#   'incid_lag': True,
#   'incid_lag_start': 3,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 14,
#   'depth': 3,
#   'MAE': 5.687892011339121,
#   'features': Index(['incid_hosp(t-1)'], dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)'], dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#                 subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': None},
#  {'columns_to_keep': ['incid_hosp', 'date', 'code_insee'],
#   'cols_to_lag': None,
#   'incid_lag': True,
#   'incid_lag_start': 4,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 14,
#   'depth': 3,
#   'MAE': 5.590597506059279,
#   'features': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)'], dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#                 subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': None},
#  {'columns_to_keep': ['incid_hosp', 'date', 'code_insee'],
#   'cols_to_lag': None,
#   'incid_lag': True,
#   'incid_lag_start': 5,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 14,
#   'depth': 3,
#   'MAE': 5.535865446128468,
#   'features': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)'], dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#                 subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': None},
#  {'columns_to_keep': ['incid_hosp', 'date', 'code_insee'],
#   'cols_to_lag': None,
#   'incid_lag': True,
#   'incid_lag_start': 6,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 14,
#   'depth': 3,
#   'MAE': 5.483196935957611,
#   'features': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)'], dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#                 subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': None},
#  {'columns_to_keep': ['incid_hosp', 'date', 'code_insee'],
#   'cols_to_lag': None,
#   'incid_lag': True,
#   'incid_lag_start': 7,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 14,
#   'depth': 3,
#   'MAE': 5.272442127734718,
#   'features': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)'], dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#                 subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': None},
#  {'columns_to_keep': ['incid_hosp', 'date', 'code_insee'],
#   'cols_to_lag': None,
#   'incid_lag': True,
#   'incid_lag_start': 8,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 14,
#   'depth': 3,
#   'MAE': 5.1892019502892355,
#   'features': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)'], dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'incid_hosp(t-8)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#                 subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': None},
#  {'columns_to_keep': ['incid_hosp', 'date', 'code_insee'],
#   'cols_to_lag': None,
#   'incid_lag': True,
#   'incid_lag_start': 9,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 14,
#   'depth': 3,
#   'MAE': 5.187841103439874,
#   'features': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)'], dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'incid_hosp(t-8)', 'incid_hosp(t-9)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#                 subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': None},
#  {'columns_to_keep': ['incid_hosp', 'date', 'code_insee'],
#   'cols_to_lag': None,
#   'incid_lag': True,
#   'incid_lag_start': 10,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 14,
#   'depth': 3,
#   'MAE': 5.0900090859815625,
#   'features': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)'],
#         dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'incid_hosp(t-8)', 'incid_hosp(t-9)',
#          'incid_hosp(t-10)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#                 subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': None},
#  {'columns_to_keep': ['incid_hosp', 'date', 'code_insee'],
#   'cols_to_lag': None,
#   'incid_lag': True,
#   'incid_lag_start': 11,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 14,
#   'depth': 3,
#   'MAE': 5.135653663979898,
#   'features': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)'],
#         dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'incid_hosp(t-8)', 'incid_hosp(t-9)',
#          'incid_hosp(t-10)', 'incid_hosp(t-11)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#                 subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': None},
#  {'columns_to_keep': ['incid_hosp', 'date', 'code_insee'],
#   'cols_to_lag': None,
#   'incid_lag': True,
#   'incid_lag_start': 12,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 14,
#   'depth': 3,
#   'MAE': 5.115250183730432,
#   'features': Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', 'incid_hosp(t-7)'], dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'incid_hosp(t-8)', 'incid_hosp(t-9)',
#          'incid_hosp(t-10)', 'incid_hosp(t-11)', 'incid_hosp(t-12)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#                 subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': None},
#  {'columns_to_keep': ['incid_hosp', 'date', 'code_insee'],
#   'cols_to_lag': None,
#   'incid_lag': True,
#   'incid_lag_start': 13,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 14,
#   'depth': 3,
#   'MAE': 5.052011179009287,
#   'features': Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', 'incid_hosp(t-7)'], dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'incid_hosp(t-8)', 'incid_hosp(t-9)',
#          'incid_hosp(t-10)', 'incid_hosp(t-11)', 'incid_hosp(t-12)',
#          'incid_hosp(t-13)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#                 subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': None},
#  {'columns_to_keep': ['incid_hosp', 'date', 'code_insee'],
#   'cols_to_lag': None,
#   'incid_lag': True,
#   'incid_lag_start': 14,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 14,
#   'depth': 3,
#   'MAE': 4.991719064109101,
#   'features': Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', 'incid_hosp(t-7)'], dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'incid_hosp(t-8)', 'incid_hosp(t-9)',
#          'incid_hosp(t-10)', 'incid_hosp(t-11)', 'incid_hosp(t-12)',
#          'incid_hosp(t-13)', 'incid_hosp(t-14)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#                 subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': None},
#  {'columns_to_keep': ['incid_hosp', 'date', 'code_insee'],
#   'cols_to_lag': None,
#   'incid_lag': True,
#   'incid_lag_start': 15,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 14,
#   'depth': 3,
#   'MAE': 4.924134063137935,
#   'features': Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', 'incid_hosp(t-7)',
#          'incid_hosp(t-8)'],
#         dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'incid_hosp(t-8)', 'incid_hosp(t-9)',
#          'incid_hosp(t-10)', 'incid_hosp(t-11)', 'incid_hosp(t-12)',
#          'incid_hosp(t-13)', 'incid_hosp(t-14)', 'incid_hosp(t-15)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#                 subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': None},
#  {'columns_to_keep': ['incid_hosp', 'date', 'code_insee'],
#   'cols_to_lag': None,
#   'incid_lag': True,
#   'incid_lag_start': 16,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 14,
#   'depth': 3,
#   'MAE': 5.051243310591372,
#   'features': Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', 'incid_hosp(t-7)',
#          'incid_hosp(t-8)'],
#         dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'incid_hosp(t-8)', 'incid_hosp(t-9)',
#          'incid_hosp(t-10)', 'incid_hosp(t-11)', 'incid_hosp(t-12)',
#          'incid_hosp(t-13)', 'incid_hosp(t-14)', 'incid_hosp(t-15)',
#          'incid_hosp(t-16)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#                 subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': None},
#  {'columns_to_keep': ['incid_hosp', 'date', 'code_insee'],
#   'cols_to_lag': None,
#   'incid_lag': True,
#   'incid_lag_start': 17,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 14,
#   'depth': 3,
#   'MAE': 4.996208604277656,
#   'features': Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', 'incid_hosp(t-7)',
#          'incid_hosp(t-8)'],
#         dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'incid_hosp(t-8)', 'incid_hosp(t-9)',
#          'incid_hosp(t-10)', 'incid_hosp(t-11)', 'incid_hosp(t-12)',
#          'incid_hosp(t-13)', 'incid_hosp(t-14)', 'incid_hosp(t-15)',
#          'incid_hosp(t-16)', 'incid_hosp(t-17)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#                 subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': None},
#  {'columns_to_keep': ['incid_hosp', 'date', 'code_insee'],
#   'cols_to_lag': None,
#   'incid_lag': True,
#   'incid_lag_start': 18,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 14,
#   'depth': 3,
#   'MAE': 5.018024973165576,
#   'features': Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', 'incid_hosp(t-7)',
#          'incid_hosp(t-8)'],
#         dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'incid_hosp(t-8)', 'incid_hosp(t-9)',
#          'incid_hosp(t-10)', 'incid_hosp(t-11)', 'incid_hosp(t-12)',
#          'incid_hosp(t-13)', 'incid_hosp(t-14)', 'incid_hosp(t-15)',
#          'incid_hosp(t-16)', 'incid_hosp(t-17)', 'incid_hosp(t-18)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#                 subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': None},
#  {'columns_to_keep': ['incid_hosp', 'date', 'code_insee'],
#   'cols_to_lag': None,
#   'incid_lag': True,
#   'incid_lag_start': 19,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 14,
#   'depth': 3,
#   'MAE': 5.008544005785543,
#   'features': Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', 'incid_hosp(t-7)',
#          'incid_hosp(t-8)'],
#         dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'incid_hosp(t-8)', 'incid_hosp(t-9)',
#          'incid_hosp(t-10)', 'incid_hosp(t-11)', 'incid_hosp(t-12)',
#          'incid_hosp(t-13)', 'incid_hosp(t-14)', 'incid_hosp(t-15)',
#          'incid_hosp(t-16)', 'incid_hosp(t-17)', 'incid_hosp(t-18)',
#          'incid_hosp(t-19)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#                 subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': None},
#  {'columns_to_keep': ['incid_hosp', 'date', 'code_insee'],
#   'cols_to_lag': None,
#   'incid_lag': True,
#   'incid_lag_start': 20,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 14,
#   'depth': 3,
#   'MAE': 4.889374626284041,
#   'features': Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', 'incid_hosp(t-7)',
#          'incid_hosp(t-8)'],
#         dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'incid_hosp(t-8)', 'incid_hosp(t-9)',
#          'incid_hosp(t-10)', 'incid_hosp(t-11)', 'incid_hosp(t-12)',
#          'incid_hosp(t-13)', 'incid_hosp(t-14)', 'incid_hosp(t-15)',
#          'incid_hosp(t-16)', 'incid_hosp(t-17)', 'incid_hosp(t-18)',
#          'incid_hosp(t-19)', 'incid_hosp(t-20)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#                 subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': None},
#  {'columns_to_keep': ['incid_hosp', 'date', 'code_insee'],
#   'cols_to_lag': None,
#   'incid_lag': True,
#   'incid_lag_start': 21,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 14,
#   'depth': 3,
#   'MAE': 4.974490313726191,
#   'features': Index(['incid_hosp(t-6)', 'incid_hosp(t-7)', 'incid_hosp(t-8)',
#          'incid_hosp(t-14)'],
#         dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'incid_hosp(t-8)', 'incid_hosp(t-9)',
#          'incid_hosp(t-10)', 'incid_hosp(t-11)', 'incid_hosp(t-12)',
#          'incid_hosp(t-13)', 'incid_hosp(t-14)', 'incid_hosp(t-15)',
#          'incid_hosp(t-16)', 'incid_hosp(t-17)', 'incid_hosp(t-18)',
#          'incid_hosp(t-19)', 'incid_hosp(t-20)', 'incid_hosp(t-21)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
# ...
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#                 subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': 'auto_gr_incid_7_mob17-21.pickle'},
#  {'columns_to_keep': ['incid_hosp',
#    'betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'date',
#    'code_insee'],
#   'cols_to_lag': ['betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16'],
#   'incid_lag': True,
#   'incid_lag_start': 7,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 16,
#   'depth': 3,
#   'MAE': 8.784770074507326,
#   'features': Index(['closeness_centrality-0_8', 'incid_hosp(t-1)', 'incid_hosp(t-2)',
#          'incid_hosp(t-3)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'closeness_centrality-16_0(t-16)',
#          'eigenvector_centrality-16_0(t-19)', 'eigenvector_centrality-0_8(t-21)',
#          'closeness_centrality-8_16(t-16)', 'eigenvector_centrality-8_16(t-19)'],
#         dtype='object'),
#   'model_input_cols': Index(['betweenness_centrality-16_0', 'closeness_centrality-16_0',
#          'degree_centrality-16_0', 'eigenvector_centrality-16_0',
#          'betweenness_centrality-0_8', 'closeness_centrality-0_8',
#          'degree_centrality-0_8', 'eigenvector_centrality-0_8',
#          'betweenness_centrality-8_16', 'closeness_centrality-8_16',
#          'degree_centrality-8_16', 'eigenvector_centrality-8_16',
#          'incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'betweenness_centrality-16_0(t-16)',
#          'betweenness_centrality-16_0(t-17)',
#          'betweenness_centrality-16_0(t-18)',
#          'betweenness_centrality-16_0(t-19)',
#          'betweenness_centrality-16_0(t-20)',
#          'betweenness_centrality-16_0(t-21)', 'closeness_centrality-16_0(t-16)',
#          'closeness_centrality-16_0(t-17)', 'closeness_centrality-16_0(t-18)',
#          'closeness_centrality-16_0(t-19)', 'closeness_centrality-16_0(t-20)',
#          'closeness_centrality-16_0(t-21)', 'degree_centrality-16_0(t-16)',
#          'degree_centrality-16_0(t-17)', 'degree_centrality-16_0(t-18)',
#          'degree_centrality-16_0(t-19)', 'degree_centrality-16_0(t-20)',
#          'degree_centrality-16_0(t-21)', 'eigenvector_centrality-16_0(t-16)',
#          'eigenvector_centrality-16_0(t-17)',
#          'eigenvector_centrality-16_0(t-18)',
#          'eigenvector_centrality-16_0(t-19)',
#          'eigenvector_centrality-16_0(t-20)',
#          'eigenvector_centrality-16_0(t-21)', 'betweenness_centrality-0_8(t-16)',
#          'betweenness_centrality-0_8(t-17)', 'betweenness_centrality-0_8(t-18)',
#          'betweenness_centrality-0_8(t-19)', 'betweenness_centrality-0_8(t-20)',
#          'betweenness_centrality-0_8(t-21)', 'closeness_centrality-0_8(t-16)',
#          'closeness_centrality-0_8(t-17)', 'closeness_centrality-0_8(t-18)',
#          'closeness_centrality-0_8(t-19)', 'closeness_centrality-0_8(t-20)',
#          'closeness_centrality-0_8(t-21)', 'degree_centrality-0_8(t-16)',
#          'degree_centrality-0_8(t-17)', 'degree_centrality-0_8(t-18)',
#          'degree_centrality-0_8(t-19)', 'degree_centrality-0_8(t-20)',
#          'degree_centrality-0_8(t-21)', 'eigenvector_centrality-0_8(t-16)',
#          'eigenvector_centrality-0_8(t-17)', 'eigenvector_centrality-0_8(t-18)',
#          'eigenvector_centrality-0_8(t-19)', 'eigenvector_centrality-0_8(t-20)',
#          'eigenvector_centrality-0_8(t-21)', 'betweenness_centrality-8_16(t-16)',
#          'betweenness_centrality-8_16(t-17)',
#          'betweenness_centrality-8_16(t-18)',
#          'betweenness_centrality-8_16(t-19)',
#          'betweenness_centrality-8_16(t-20)',
#          'betweenness_centrality-8_16(t-21)', 'closeness_centrality-8_16(t-16)',
#          'closeness_centrality-8_16(t-17)', 'closeness_centrality-8_16(t-18)',
#          'closeness_centrality-8_16(t-19)', 'closeness_centrality-8_16(t-20)',
#          'closeness_centrality-8_16(t-21)', 'degree_centrality-8_16(t-16)',
#          'degree_centrality-8_16(t-17)', 'degree_centrality-8_16(t-18)',
#          'degree_centrality-8_16(t-19)', 'degree_centrality-8_16(t-20)',
#          'degree_centrality-8_16(t-21)', 'eigenvector_centrality-8_16(t-16)',
#          'eigenvector_centrality-8_16(t-17)',
#          'eigenvector_centrality-8_16(t-18)',
#          'eigenvector_centrality-8_16(t-19)',
#          'eigenvector_centrality-8_16(t-20)',
#          'eigenvector_centrality-8_16(t-21)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#                 subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': 'auto_gr_incid_7_mob16-21.pickle'},
#  {'columns_to_keep': ['incid_hosp',
#    'betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'date',
#    'code_insee'],
#   'cols_to_lag': ['betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16'],
#   'incid_lag': True,
#   'incid_lag_start': 7,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 15,
#   'depth': 3,
#   'MAE': 9.426609226063938,
#   'features': Index(['closeness_centrality-0_8', 'incid_hosp(t-1)', 'incid_hosp(t-2)',
#          'incid_hosp(t-3)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'betweenness_centrality-16_0(t-21)',
#          'eigenvector_centrality-16_0(t-21)', 'closeness_centrality-0_8(t-15)',
#          'eigenvector_centrality-0_8(t-21)', 'closeness_centrality-8_16(t-15)'],
#         dtype='object'),
#   'model_input_cols': Index(['betweenness_centrality-16_0', 'closeness_centrality-16_0',
#          'degree_centrality-16_0', 'eigenvector_centrality-16_0',
#          'betweenness_centrality-0_8', 'closeness_centrality-0_8',
#          'degree_centrality-0_8', 'eigenvector_centrality-0_8',
#          'betweenness_centrality-8_16', 'closeness_centrality-8_16',
#          ...
#          'degree_centrality-8_16(t-19)', 'degree_centrality-8_16(t-20)',
#          'degree_centrality-8_16(t-21)', 'eigenvector_centrality-8_16(t-15)',
#          'eigenvector_centrality-8_16(t-16)',
#          'eigenvector_centrality-8_16(t-17)',
#          'eigenvector_centrality-8_16(t-18)',
#          'eigenvector_centrality-8_16(t-19)',
#          'eigenvector_centrality-8_16(t-20)',
#          'eigenvector_centrality-8_16(t-21)'],
#         dtype='object', length=103),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#                 subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': 'auto_gr_incid_7_mob15-21.pickle'},
#  {'columns_to_keep': ['incid_hosp',
#    'betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'date',
#    'code_insee'],
#   'cols_to_lag': ['betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16'],
#   'incid_lag': True,
#   'incid_lag_start': 7,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 14,
#   'depth': 3,
#   'MAE': 8.922580733733492,
#   'features': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-5)', 'incid_hosp(t-6)', 'incid_hosp(t-7)',
#          'betweenness_centrality-16_0(t-14)',
#          'betweenness_centrality-16_0(t-21)',
#          'eigenvector_centrality-16_0(t-15)', 'eigenvector_centrality-0_8(t-19)',
#          'eigenvector_centrality-0_8(t-21)', 'closeness_centrality-8_16(t-15)',
#          'eigenvector_centrality-8_16(t-19)'],
#         dtype='object'),
#   'model_input_cols': Index(['betweenness_centrality-16_0', 'closeness_centrality-16_0',
#          'degree_centrality-16_0', 'eigenvector_centrality-16_0',
#          'betweenness_centrality-0_8', 'closeness_centrality-0_8',
#          'degree_centrality-0_8', 'eigenvector_centrality-0_8',
#          'betweenness_centrality-8_16', 'closeness_centrality-8_16',
#          ...
#          'degree_centrality-8_16(t-20)', 'degree_centrality-8_16(t-21)',
#          'eigenvector_centrality-8_16(t-14)',
#          'eigenvector_centrality-8_16(t-15)',
#          'eigenvector_centrality-8_16(t-16)',
#          'eigenvector_centrality-8_16(t-17)',
#          'eigenvector_centrality-8_16(t-18)',
#          'eigenvector_centrality-8_16(t-19)',
#          'eigenvector_centrality-8_16(t-20)',
#          'eigenvector_centrality-8_16(t-21)'],
#         dtype='object', length=115),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'reg:linear',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#                 reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#                 subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': 'auto_gr_incid_7_mob14-21.pickle'}]

# %% [markdown]
# With maximum 13 days past, the result does not change.

# %% [markdown]
# # Graph features without auto-regressive features

# %% [markdown]
# Can we predict without the auto-regressive features? Apparently not.

# %%
cols = ['incid_hosp','betweenness_centrality-16_0', 'closeness_centrality-16_0',
               'degree_centrality-16_0', 'eigenvector_centrality-16_0',
               'betweenness_centrality-0_8', 'closeness_centrality-0_8',
               'degree_centrality-0_8', 'eigenvector_centrality-0_8',
               'betweenness_centrality-8_16', 'closeness_centrality-8_16',
               'degree_centrality-8_16', 'eigenvector_centrality-8_16', 'date','code_insee']

cols_to_lag = ['betweenness_centrality-16_0', 'closeness_centrality-16_0',
               'degree_centrality-16_0', 'eigenvector_centrality-16_0',
               'betweenness_centrality-0_8', 'closeness_centrality-0_8',
               'degree_centrality-0_8', 'eigenvector_centrality-0_8',
               'betweenness_centrality-8_16', 'closeness_centrality-8_16',
               'degree_centrality-8_16', 'eigenvector_centrality-8_16']

for i in range(10,22):
    for j in range(1, 8):
        dico = expe('auto_gr_incid_7_mob{}-{}.pickle'.format(i-j,i),cols, cols_to_lag ,incid_lag = False, incid_lag_start = 7,
            incid_lag_end = 1, col_lag_start = i, col_lag_end = i-j)
        results.append(dico)
    
        results.append(dico)
# Out:
# MAE: 19.13 train shape:  (1308, 37) mov window:  10 9
# MAE: 19.84 train shape:  (1233, 49) mov window:  10 8
# MAE: 20.69 train shape:  (1185, 61) mov window:  10 7
# MAE: 21.14 train shape:  (1110, 73) mov window:  10 6
# MAE: 20.33 train shape:  (1031, 85) mov window:  10 5
# MAE: 18.96 train shape:  (974, 97) mov window:  10 4
# MAE: 19.45 train shape:  (957, 109) mov window:  10 3
# MAE: 17.64 train shape:  (1254, 37) mov window:  11 10
# MAE: 19.12 train shape:  (1158, 49) mov window:  11 9
# MAE: 19.43 train shape:  (1094, 61) mov window:  11 8
# MAE: 20.54 train shape:  (1057, 73) mov window:  11 7
# MAE: 20.12 train shape:  (987, 85) mov window:  11 6
# MAE: 19.73 train shape:  (931, 97) mov window:  11 5
# MAE: 19.15 train shape:  (914, 109) mov window:  11 4
# MAE: 18.56 train shape:  (1183, 37) mov window:  12 11
# MAE: 18.72 train shape:  (1087, 49) mov window:  12 10
# MAE: 18.99 train shape:  (1016, 61) mov window:  12 9
# MAE: 19.02 train shape:  (970, 73) mov window:  12 8
# MAE: 20.33 train shape:  (934, 85) mov window:  12 7
# MAE: 20.32 train shape:  (885, 97) mov window:  12 6
# MAE: 19.94 train shape:  (869, 109) mov window:  12 5
# MAE: 18.19 train shape:  (1128, 37) mov window:  13 12
# MAE: 18.72 train shape:  (1031, 49) mov window:  13 11
# MAE: 18.75 train shape:  (960, 61) mov window:  13 10
# MAE: 18.76 train shape:  (907, 73) mov window:  13 9
# MAE: 19.24 train shape:  (863, 85) mov window:  13 8
# MAE: 20.39 train shape:  (839, 97) mov window:  13 7
# MAE: 20.19 train shape:  (825, 109) mov window:  13 6
# MAE: 17.35 train shape:  (1111, 37) mov window:  14 13
# MAE: 18.58 train shape:  (1014, 49) mov window:  14 12
# MAE: 18.78 train shape:  (942, 61) mov window:  14 11
# MAE: 18.31 train shape:  (887, 73) mov window:  14 10
# MAE: 18.44 train shape:  (837, 85) mov window:  14 9
# MAE: 19.23 train shape:  (797, 97) mov window:  14 8
# MAE: 20.50 train shape:  (783, 109) mov window:  14 7
# MAE: 18.18 train shape:  (1051, 37) mov window:  15 14
# MAE: 18.38 train shape:  (957, 49) mov window:  15 13
# MAE: 18.26 train shape:  (887, 61) mov window:  15 12
# MAE: 18.98 train shape:  (835, 73) mov window:  15 11
# MAE: 18.38 train shape:  (784, 85) mov window:  15 10
# MAE: 18.45 train shape:  (749, 97) mov window:  15 9
# MAE: 19.63 train shape:  (738, 109) mov window:  15 8
# MAE: 17.40 train shape:  (965, 37) mov window:  16 15
# MAE: 18.24 train shape:  (912, 49) mov window:  16 14
# MAE: 18.13 train shape:  (844, 61) mov window:  16 13
# MAE: 18.00 train shape:  (792, 73) mov window:  16 12
# MAE: 18.00 train shape:  (741, 85) mov window:  16 11
# MAE: 18.44 train shape:  (706, 97) mov window:  16 10
# MAE: 18.52 train shape:  (698, 109) mov window:  16 9
# MAE: 16.07 train shape:  (895, 37) mov window:  17 16
# MAE: 16.97 train shape:  (831, 49) mov window:  17 15
# MAE: 17.54 train shape:  (798, 61) mov window:  17 14
# MAE: 18.98 train shape:  (748, 73) mov window:  17 13
# MAE: 18.36 train shape:  (698, 85) mov window:  17 12
# MAE: 17.91 train shape:  (663, 97) mov window:  17 11
# MAE: 17.29 train shape:  (655, 109) mov window:  17 10
# MAE: 14.68 train shape:  (847, 37) mov window:  18 17
# MAE: 15.60 train shape:  (780, 49) mov window:  18 16
# MAE: 16.94 train shape:  (730, 61) mov window:  18 15
# MAE: 18.33 train shape:  (706, 73) mov window:  18 14
# MAE: 18.27 train shape:  (658, 85) mov window:  18 13
# MAE: 18.18 train shape:  (624, 97) mov window:  18 12
# MAE: 17.62 train shape:  (616, 109) mov window:  18 11
# MAE: 14.61 train shape:  (771, 37) mov window:  19 18
# MAE: 15.57 train shape:  (712, 49) mov window:  19 17
# MAE: 16.05 train shape:  (669, 61) mov window:  19 16
# MAE: 16.95 train shape:  (637, 73) mov window:  19 15
# MAE: 18.22 train shape:  (613, 85) mov window:  19 14
# MAE: 17.97 train shape:  (581, 97) mov window:  19 13
# MAE: 17.57 train shape:  (573, 109) mov window:  19 12
# MAE: 14.42 train shape:  (708, 37) mov window:  20 19
# MAE: 14.80 train shape:  (648, 49) mov window:  20 18
# MAE: 15.52 train shape:  (612, 61) mov window:  20 17
# MAE: 16.07 train shape:  (585, 73) mov window:  20 16
# MAE: 16.60 train shape:  (553, 85) mov window:  20 15
# MAE: 17.51 train shape:  (539, 97) mov window:  20 14
# MAE: 17.29 train shape:  (531, 109) mov window:  20 13
# MAE: 14.37 train shape:  (671, 37) mov window:  21 20
# MAE: 15.55 train shape:  (608, 49) mov window:  21 19
# MAE: 15.95 train shape:  (572, 61) mov window:  21 18
# MAE: 16.94 train shape:  (551, 73) mov window:  21 17
# MAE: 17.13 train shape:  (524, 85) mov window:  21 16
# MAE: 16.80 train shape:  (495, 97) mov window:  21 15
# MAE: 17.34 train shape:  (491, 109) mov window:  21 14

# %% [markdown]
# # Graph, movement and autoregressive, more depth to xgboost

# %%
# depth 5
cols = ['incid_hosp', 
       'betweenness_centrality-16_0', 'closeness_centrality-16_0',
       'degree_centrality-16_0', 'eigenvector_centrality-16_0',
       'betweenness_centrality-0_8', 'closeness_centrality-0_8',
       'degree_centrality-0_8', 'eigenvector_centrality-0_8',
       'betweenness_centrality-8_16', 'closeness_centrality-8_16',
       'degree_centrality-8_16', 'eigenvector_centrality-8_16', 
       'length_km', 'movement', 'movement_baseline', 'movement_difference',
       'movement_percent_change', 'density_weighted_movement','date','code_insee']

cols_to_lag = ['betweenness_centrality-16_0', 'closeness_centrality-16_0',
               'degree_centrality-16_0', 'eigenvector_centrality-16_0',
               'betweenness_centrality-0_8', 'closeness_centrality-0_8',
               'degree_centrality-0_8', 'eigenvector_centrality-0_8',
               'betweenness_centrality-8_16', 'closeness_centrality-8_16',
               'degree_centrality-8_16', 'eigenvector_centrality-8_16', 'length_km', 'movement', 'movement_baseline', 'movement_difference',
       'movement_percent_change', 'density_weighted_movement']

for i in range(10,22):
    for j in range(2, 7):
        dico = expe(cols, cols_to_lag ,incid_lag = True, incid_lag_start = 7,
            incid_lag_end = 1, col_lag_start = i+j, col_lag_end = i, depth = 5)
    
        results.append(dico)
# Out:
# MAE: 7.06 (864, 80)
# MAE: 7.38 (787, 98)
# MAE: 7.55 (712, 116)
# MAE: 7.58 (637, 134)
# MAE: 7.55 (563, 152)
# MAE: 7.45 (787, 80)
# MAE: 7.50 (712, 98)
# MAE: 7.49 (637, 116)
# MAE: 7.52 (563, 134)
# MAE: 8.18 (489, 152)
# MAE: 7.59 (712, 80)
# MAE: 7.45 (637, 98)
# MAE: 7.49 (563, 116)
# MAE: 8.27 (489, 134)
# MAE: 8.11 (418, 152)
# MAE: 7.46 (637, 80)
# MAE: 7.69 (563, 98)
# MAE: 8.19 (489, 116)
# MAE: 8.39 (418, 134)
# MAE: 8.65 (351, 152)
# MAE: 7.52 (563, 80)
# MAE: 8.04 (489, 98)
# MAE: 8.41 (418, 116)
# MAE: 8.51 (351, 134)
# MAE: 8.36 (288, 152)
# MAE: 8.22 (489, 80)
# MAE: 8.47 (418, 98)
# MAE: 8.44 (351, 116)
# MAE: 8.42 (288, 134)
# MAE: 8.70 (231, 152)
# MAE: 8.36 (418, 80)
# MAE: 8.66 (351, 98)
# MAE: 8.66 (288, 116)
# MAE: 8.74 (231, 134)
# MAE: 8.24 (176, 152)
# MAE: 8.07 (351, 80)
# MAE: 8.72 (288, 98)
# MAE: 8.42 (231, 116)
# MAE: 8.28 (176, 134)
# MAE: 7.55 (126, 152)
# MAE: 8.61 (288, 80)
# MAE: 8.26 (231, 98)
# MAE: 8.20 (176, 116)
# MAE: 7.44 (126, 134)
# MAE: 7.91 (77, 152)
# MAE: 8.20 (231, 80)
# MAE: 7.80 (176, 98)
# MAE: 7.51 (126, 116)
# MAE: 7.34 (77, 134)
# MAE: 7.28 (36, 152)
# MAE: 8.14 (176, 80)
# MAE: 7.33 (126, 98)
# MAE: 7.33 (77, 116)
# MAE: 7.21 (36, 134)
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# <ipython-input-799-6c26dfb6f926> in <module>
#      21     for j in range(2, 7):
#      22         dico = expe(cols, cols_to_lag ,incid_lag = True, incid_lag_start = 7,
# ---> 23             incid_lag_end = 1, col_lag_start = i+j, col_lag_end = i, depth = 5)
#      24
#      25         results.append(dico)
#
# <ipython-input-796-64febd096e2f> in expe(columns_to_keep, cols_to_lag, incid_lag, incid_lag_start, incid_lag_end, col_lag_start, col_lag_end, depth)
#      19     # fit model on all training data
#      20     model = XGBRegressor(cv = tscv, silent = True, max_depth = depth)
# ---> 21     model.fit(X_train, y_train)
#      22
#      23     # make predictions for test data and evaluate
#
# //anaconda3/lib/python3.7/site-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     394                               evals_result=evals_result, obj=obj, feval=feval,
#     395                               verbose_eval=verbose, xgb_model=xgb_model,
# --> 396                               callbacks=callbacks)
#     397
#     398         if evals_result:
#
# //anaconda3/lib/python3.7/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
#     215                            obj=obj, feval=feval,
# --> 216                            xgb_model=xgb_model, callbacks=callbacks)
#     217
#     218
#
# //anaconda3/lib/python3.7/site-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# //anaconda3/lib/python3.7/site-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1107         if fobj is None:
#    1108             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# -> 1109                                                     dtrain.handle))
#    1110         else:
#    1111             pred = self.predict(dtrain)
#
# //anaconda3/lib/python3.7/site-packages/xgboost/core.py in _check_call(ret)
#     174     """
#     175     if ret != 0:
# --> 176         raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#     177
#     178
#
# XGBoostError: [00:41:45] src/objective/regression_obj.cu:64: Check failed: info.labels_.Size() != 0U (0 vs. 0) : label set cannot be empty
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x0000001a38ec5469 dmlc::LogMessageFatal::~LogMessageFatal() + 57
#   [bt] (1) 2   libxgboost.dylib                    0x0000001a38f49b29 xgboost::obj::RegLossObj<xgboost::obj::LinearSquareLoss>::GetGradient(xgboost::HostDeviceVector<float> const&, xgboost::MetaInfo const&, int, xgboost::HostDeviceVector<xgboost::detail::GradientPairInternal<float> >*) + 281
#   [bt] (2) 3   libxgboost.dylib                    0x0000001a38ec10ee xgboost::LearnerImpl::UpdateOneIter(int, xgboost::DMatrix*) + 1278
#   [bt] (3) 4   libxgboost.dylib                    0x0000001a38ee1f9c XGBoosterUpdateOneIter + 172
#   [bt] (4) 5   libffi.6.dylib                      0x000000010fec3884 ffi_call_unix64 + 76
#   [bt] (5) 6   ???                                 0x00007ffee14aea70 0x0 + 140732678204016

# %%
# depth 10, without looping over mobility windows
cols = ['incid_hosp', 
       'betweenness_centrality-16_0', 'closeness_centrality-16_0',
       'degree_centrality-16_0', 'eigenvector_centrality-16_0',
       'betweenness_centrality-0_8', 'closeness_centrality-0_8',
       'degree_centrality-0_8', 'eigenvector_centrality-0_8',
       'betweenness_centrality-8_16', 'closeness_centrality-8_16',
       'degree_centrality-8_16', 'eigenvector_centrality-8_16', 
       'length_km', 'movement', 'movement_baseline', 'movement_difference',
       'movement_percent_change', 'density_weighted_movement','date','code_insee']

cols_to_lag = ['betweenness_centrality-16_0', 'closeness_centrality-16_0',
               'degree_centrality-16_0', 'eigenvector_centrality-16_0',
               'betweenness_centrality-0_8', 'closeness_centrality-0_8',
               'degree_centrality-0_8', 'eigenvector_centrality-0_8',
               'betweenness_centrality-8_16', 'closeness_centrality-8_16',
               'degree_centrality-8_16', 'eigenvector_centrality-8_16', 'length_km', 'movement', 'movement_baseline', 'movement_difference',
       'movement_percent_change', 'density_weighted_movement']

dico = expe(cols, cols_to_lag ,incid_lag = True, incid_lag_start = 7,
    incid_lag_end = 1, col_lag_start = 21, col_lag_end = 14, depth = 10)
    
results.append(dico)
# Out:
# MAE: 8.65 (231, 170)

# %%
# depth vary, without looping over mobility windows
scores =  []
cols = ['incid_hosp', 
       'betweenness_centrality-16_0', 'closeness_centrality-16_0',
       'degree_centrality-16_0', 'eigenvector_centrality-16_0',
       'betweenness_centrality-0_8', 'closeness_centrality-0_8',
       'degree_centrality-0_8', 'eigenvector_centrality-0_8',
       'betweenness_centrality-8_16', 'closeness_centrality-8_16',
       'degree_centrality-8_16', 'eigenvector_centrality-8_16', 
       'length_km', 'movement', 'movement_baseline', 'movement_difference',
       'movement_percent_change', 'density_weighted_movement','date','code_insee']

cols_to_lag = ['betweenness_centrality-16_0', 'closeness_centrality-16_0',
               'degree_centrality-16_0', 'eigenvector_centrality-16_0',
               'betweenness_centrality-0_8', 'closeness_centrality-0_8',
               'degree_centrality-0_8', 'eigenvector_centrality-0_8',
               'betweenness_centrality-8_16', 'closeness_centrality-8_16',
               'degree_centrality-8_16', 'eigenvector_centrality-8_16', 'length_km', 'movement', 'movement_baseline', 'movement_difference',
       'movement_percent_change', 'density_weighted_movement']
for i in range(3,30):
    dico = expe(cols, cols_to_lag ,incid_lag = True, incid_lag_start = 7,
        incid_lag_end = 1, col_lag_start = 21, col_lag_end = 18, depth = i)

    scores.append(dico)
# Out:
# MAE: 9.08 (231, 170)
# MAE: 8.60 (231, 170)
# MAE: 8.56 (231, 170)
# MAE: 8.67 (231, 170)
# MAE: 8.49 (231, 170)
# MAE: 8.59 (231, 170)
# MAE: 8.61 (231, 170)
# MAE: 8.65 (231, 170)
# MAE: 8.69 (231, 170)
# MAE: 8.67 (231, 170)
# MAE: 8.88 (231, 170)
# MAE: 8.90 (231, 170)
# MAE: 8.89 (231, 170)
# MAE: 8.87 (231, 170)
# MAE: 8.87 (231, 170)
# MAE: 8.87 (231, 170)
# MAE: 8.87 (231, 170)
# MAE: 8.87 (231, 170)
# MAE: 8.87 (231, 170)
# MAE: 8.87 (231, 170)
# MAE: 8.87 (231, 170)
# MAE: 8.87 (231, 170)
# MAE: 8.87 (231, 170)
# MAE: 8.87 (231, 170)
# MAE: 8.87 (231, 170)
# MAE: 8.87 (231, 170)
# MAE: 8.87 (231, 170)

# %% [markdown]
# # Generate report

# %%
results
# Out:
# [{'columns_to_keep': ['incid_hosp',
#    'betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement',
#    'date',
#    'code_insee'],
#   'cols_to_lag': ['betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement'],
#   'incid_lag': True,
#   'incid_lag_start': 7,
#   'incid_lag_end': 1,
#   'col_lag_start': 10,
#   'col_lag_end': 9,
#   'depth': 3,
#   'MAE': 6.697732945946692,
#   'features': Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', 'incid_hosp(t-7)'], dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'betweenness_centrality-16_0(t-9)',
#          'betweenness_centrality-16_0(t-10)', 'closeness_centrality-16_0(t-9)',
#          'closeness_centrality-16_0(t-10)', 'degree_centrality-16_0(t-9)',
#          'degree_centrality-16_0(t-10)', 'eigenvector_centrality-16_0(t-9)',
#          'eigenvector_centrality-16_0(t-10)', 'betweenness_centrality-0_8(t-9)',
#          'betweenness_centrality-0_8(t-10)', 'closeness_centrality-0_8(t-9)',
#          'closeness_centrality-0_8(t-10)', 'degree_centrality-0_8(t-9)',
#          'degree_centrality-0_8(t-10)', 'eigenvector_centrality-0_8(t-9)',
#          'eigenvector_centrality-0_8(t-10)', 'betweenness_centrality-8_16(t-9)',
#          'betweenness_centrality-8_16(t-10)', 'closeness_centrality-8_16(t-9)',
#          'closeness_centrality-8_16(t-10)', 'degree_centrality-8_16(t-9)',
#          'degree_centrality-8_16(t-10)', 'eigenvector_centrality-8_16(t-9)',
#          'eigenvector_centrality-8_16(t-10)', 'length_km(t-9)',
#          'length_km(t-10)', 'movement(t-9)', 'movement(t-10)',
#          'movement_baseline(t-9)', 'movement_baseline(t-10)',
#          'movement_difference(t-9)', 'movement_difference(t-10)',
#          'movement_percent_change(t-9)', 'movement_percent_change(t-10)',
#          'density_weighted_movement(t-9)', 'density_weighted_movement(t-10)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'count:poisson',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='count:poisson', random_state=0,
#                 reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#                 silent=True, subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': 'obj_count_auto_mov_gr_incid_7_mob9-10.pickle'},
#  {'columns_to_keep': ['incid_hosp',
#    'betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement',
#    'date',
#    'code_insee'],
#   'cols_to_lag': ['betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement'],
#   'incid_lag': True,
#   'incid_lag_start': 7,
#   'incid_lag_end': 1,
#   'col_lag_start': 10,
#   'col_lag_end': 8,
#   'depth': 3,
#   'MAE': 6.675654553151927,
#   'features': Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', 'incid_hosp(t-7)'], dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'betweenness_centrality-16_0(t-8)',
#          'betweenness_centrality-16_0(t-9)', 'betweenness_centrality-16_0(t-10)',
#          'closeness_centrality-16_0(t-8)', 'closeness_centrality-16_0(t-9)',
#          'closeness_centrality-16_0(t-10)', 'degree_centrality-16_0(t-8)',
#          'degree_centrality-16_0(t-9)', 'degree_centrality-16_0(t-10)',
#          'eigenvector_centrality-16_0(t-8)', 'eigenvector_centrality-16_0(t-9)',
#          'eigenvector_centrality-16_0(t-10)', 'betweenness_centrality-0_8(t-8)',
#          'betweenness_centrality-0_8(t-9)', 'betweenness_centrality-0_8(t-10)',
#          'closeness_centrality-0_8(t-8)', 'closeness_centrality-0_8(t-9)',
#          'closeness_centrality-0_8(t-10)', 'degree_centrality-0_8(t-8)',
#          'degree_centrality-0_8(t-9)', 'degree_centrality-0_8(t-10)',
#          'eigenvector_centrality-0_8(t-8)', 'eigenvector_centrality-0_8(t-9)',
#          'eigenvector_centrality-0_8(t-10)', 'betweenness_centrality-8_16(t-8)',
#          'betweenness_centrality-8_16(t-9)', 'betweenness_centrality-8_16(t-10)',
#          'closeness_centrality-8_16(t-8)', 'closeness_centrality-8_16(t-9)',
#          'closeness_centrality-8_16(t-10)', 'degree_centrality-8_16(t-8)',
#          'degree_centrality-8_16(t-9)', 'degree_centrality-8_16(t-10)',
#          'eigenvector_centrality-8_16(t-8)', 'eigenvector_centrality-8_16(t-9)',
#          'eigenvector_centrality-8_16(t-10)', 'length_km(t-8)', 'length_km(t-9)',
#          'length_km(t-10)', 'movement(t-8)', 'movement(t-9)', 'movement(t-10)',
#          'movement_baseline(t-8)', 'movement_baseline(t-9)',
#          'movement_baseline(t-10)', 'movement_difference(t-8)',
#          'movement_difference(t-9)', 'movement_difference(t-10)',
#          'movement_percent_change(t-8)', 'movement_percent_change(t-9)',
#          'movement_percent_change(t-10)', 'density_weighted_movement(t-8)',
#          'density_weighted_movement(t-9)', 'density_weighted_movement(t-10)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'count:poisson',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='count:poisson', random_state=0,
#                 reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#                 silent=True, subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': 'obj_count_auto_mov_gr_incid_7_mob8-10.pickle'},
#  {'columns_to_keep': ['incid_hosp',
#    'betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement',
#    'date',
#    'code_insee'],
#   'cols_to_lag': ['betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement'],
#   'incid_lag': True,
#   'incid_lag_start': 7,
#   'incid_lag_end': 1,
#   'col_lag_start': 10,
#   'col_lag_end': 7,
#   'depth': 3,
#   'MAE': 8.135531242851737,
#   'features': Index(['incid_hosp(t-6)', 'incid_hosp(t-7)',
#          'eigenvector_centrality-16_0(t-8)', 'movement_baseline(t-7)'],
#         dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'betweenness_centrality-16_0(t-7)',
#          'betweenness_centrality-16_0(t-8)', 'betweenness_centrality-16_0(t-9)',
#          'betweenness_centrality-16_0(t-10)', 'closeness_centrality-16_0(t-7)',
#          'closeness_centrality-16_0(t-8)', 'closeness_centrality-16_0(t-9)',
#          'closeness_centrality-16_0(t-10)', 'degree_centrality-16_0(t-7)',
#          'degree_centrality-16_0(t-8)', 'degree_centrality-16_0(t-9)',
#          'degree_centrality-16_0(t-10)', 'eigenvector_centrality-16_0(t-7)',
#          'eigenvector_centrality-16_0(t-8)', 'eigenvector_centrality-16_0(t-9)',
#          'eigenvector_centrality-16_0(t-10)', 'betweenness_centrality-0_8(t-7)',
#          'betweenness_centrality-0_8(t-8)', 'betweenness_centrality-0_8(t-9)',
#          'betweenness_centrality-0_8(t-10)', 'closeness_centrality-0_8(t-7)',
#          'closeness_centrality-0_8(t-8)', 'closeness_centrality-0_8(t-9)',
#          'closeness_centrality-0_8(t-10)', 'degree_centrality-0_8(t-7)',
#          'degree_centrality-0_8(t-8)', 'degree_centrality-0_8(t-9)',
#          'degree_centrality-0_8(t-10)', 'eigenvector_centrality-0_8(t-7)',
#          'eigenvector_centrality-0_8(t-8)', 'eigenvector_centrality-0_8(t-9)',
#          'eigenvector_centrality-0_8(t-10)', 'betweenness_centrality-8_16(t-7)',
#          'betweenness_centrality-8_16(t-8)', 'betweenness_centrality-8_16(t-9)',
#          'betweenness_centrality-8_16(t-10)', 'closeness_centrality-8_16(t-7)',
#          'closeness_centrality-8_16(t-8)', 'closeness_centrality-8_16(t-9)',
#          'closeness_centrality-8_16(t-10)', 'degree_centrality-8_16(t-7)',
#          'degree_centrality-8_16(t-8)', 'degree_centrality-8_16(t-9)',
#          'degree_centrality-8_16(t-10)', 'eigenvector_centrality-8_16(t-7)',
#          'eigenvector_centrality-8_16(t-8)', 'eigenvector_centrality-8_16(t-9)',
#          'eigenvector_centrality-8_16(t-10)', 'length_km(t-7)', 'length_km(t-8)',
#          'length_km(t-9)', 'length_km(t-10)', 'movement(t-7)', 'movement(t-8)',
#          'movement(t-9)', 'movement(t-10)', 'movement_baseline(t-7)',
#          'movement_baseline(t-8)', 'movement_baseline(t-9)',
#          'movement_baseline(t-10)', 'movement_difference(t-7)',
#          'movement_difference(t-8)', 'movement_difference(t-9)',
#          'movement_difference(t-10)', 'movement_percent_change(t-7)',
#          'movement_percent_change(t-8)', 'movement_percent_change(t-9)',
#          'movement_percent_change(t-10)', 'density_weighted_movement(t-7)',
#          'density_weighted_movement(t-8)', 'density_weighted_movement(t-9)',
#          'density_weighted_movement(t-10)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'count:poisson',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='count:poisson', random_state=0,
#                 reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#                 silent=True, subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': 'obj_count_auto_mov_gr_incid_7_mob7-10.pickle'},
#  {'columns_to_keep': ['incid_hosp',
#    'betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement',
#    'date',
#    'code_insee'],
#   'cols_to_lag': ['betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement'],
#   'incid_lag': True,
#   'incid_lag_start': 7,
#   'incid_lag_end': 1,
#   'col_lag_start': 10,
#   'col_lag_end': 6,
#   'depth': 3,
#   'MAE': 8.126969007739179,
#   'features': Index(['incid_hosp(t-5)', 'incid_hosp(t-6)', 'incid_hosp(t-7)',
#          'eigenvector_centrality-16_0(t-8)', 'movement_baseline(t-7)'],
#         dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'betweenness_centrality-16_0(t-6)',
#          'betweenness_centrality-16_0(t-7)', 'betweenness_centrality-16_0(t-8)',
#          'betweenness_centrality-16_0(t-9)', 'betweenness_centrality-16_0(t-10)',
#          'closeness_centrality-16_0(t-6)', 'closeness_centrality-16_0(t-7)',
#          'closeness_centrality-16_0(t-8)', 'closeness_centrality-16_0(t-9)',
#          'closeness_centrality-16_0(t-10)', 'degree_centrality-16_0(t-6)',
#          'degree_centrality-16_0(t-7)', 'degree_centrality-16_0(t-8)',
#          'degree_centrality-16_0(t-9)', 'degree_centrality-16_0(t-10)',
#          'eigenvector_centrality-16_0(t-6)', 'eigenvector_centrality-16_0(t-7)',
#          'eigenvector_centrality-16_0(t-8)', 'eigenvector_centrality-16_0(t-9)',
#          'eigenvector_centrality-16_0(t-10)', 'betweenness_centrality-0_8(t-6)',
#          'betweenness_centrality-0_8(t-7)', 'betweenness_centrality-0_8(t-8)',
#          'betweenness_centrality-0_8(t-9)', 'betweenness_centrality-0_8(t-10)',
#          'closeness_centrality-0_8(t-6)', 'closeness_centrality-0_8(t-7)',
#          'closeness_centrality-0_8(t-8)', 'closeness_centrality-0_8(t-9)',
#          'closeness_centrality-0_8(t-10)', 'degree_centrality-0_8(t-6)',
#          'degree_centrality-0_8(t-7)', 'degree_centrality-0_8(t-8)',
#          'degree_centrality-0_8(t-9)', 'degree_centrality-0_8(t-10)',
#          'eigenvector_centrality-0_8(t-6)', 'eigenvector_centrality-0_8(t-7)',
#          'eigenvector_centrality-0_8(t-8)', 'eigenvector_centrality-0_8(t-9)',
#          'eigenvector_centrality-0_8(t-10)', 'betweenness_centrality-8_16(t-6)',
#          'betweenness_centrality-8_16(t-7)', 'betweenness_centrality-8_16(t-8)',
#          'betweenness_centrality-8_16(t-9)', 'betweenness_centrality-8_16(t-10)',
#          'closeness_centrality-8_16(t-6)', 'closeness_centrality-8_16(t-7)',
#          'closeness_centrality-8_16(t-8)', 'closeness_centrality-8_16(t-9)',
#          'closeness_centrality-8_16(t-10)', 'degree_centrality-8_16(t-6)',
#          'degree_centrality-8_16(t-7)', 'degree_centrality-8_16(t-8)',
#          'degree_centrality-8_16(t-9)', 'degree_centrality-8_16(t-10)',
#          'eigenvector_centrality-8_16(t-6)', 'eigenvector_centrality-8_16(t-7)',
#          'eigenvector_centrality-8_16(t-8)', 'eigenvector_centrality-8_16(t-9)',
#          'eigenvector_centrality-8_16(t-10)', 'length_km(t-6)', 'length_km(t-7)',
#          'length_km(t-8)', 'length_km(t-9)', 'length_km(t-10)', 'movement(t-6)',
#          'movement(t-7)', 'movement(t-8)', 'movement(t-9)', 'movement(t-10)',
#          'movement_baseline(t-6)', 'movement_baseline(t-7)',
#          'movement_baseline(t-8)', 'movement_baseline(t-9)',
#          'movement_baseline(t-10)', 'movement_difference(t-6)',
#          'movement_difference(t-7)', 'movement_difference(t-8)',
#          'movement_difference(t-9)', 'movement_difference(t-10)',
#          'movement_percent_change(t-6)', 'movement_percent_change(t-7)',
#          'movement_percent_change(t-8)', 'movement_percent_change(t-9)',
#          'movement_percent_change(t-10)', 'density_weighted_movement(t-6)',
#          'density_weighted_movement(t-7)', 'density_weighted_movement(t-8)',
#          'density_weighted_movement(t-9)', 'density_weighted_movement(t-10)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'count:poisson',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='count:poisson', random_state=0,
#                 reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#                 silent=True, subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': 'obj_count_auto_mov_gr_incid_7_mob6-10.pickle'},
#  {'columns_to_keep': ['incid_hosp',
#    'betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement',
#    'date',
#    'code_insee'],
#   'cols_to_lag': ['betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement'],
#   'incid_lag': True,
#   'incid_lag_start': 7,
#   'incid_lag_end': 1,
#   'col_lag_start': 10,
#   'col_lag_end': 5,
#   'depth': 3,
#   'MAE': 8.013447395422757,
#   'features': Index(['incid_hosp(t-5)', 'incid_hosp(t-6)', 'incid_hosp(t-7)',
#          'eigenvector_centrality-16_0(t-8)', 'movement_baseline(t-7)'],
#         dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'betweenness_centrality-16_0(t-5)',
#          'betweenness_centrality-16_0(t-6)', 'betweenness_centrality-16_0(t-7)',
#          ...
#          'movement_percent_change(t-7)', 'movement_percent_change(t-8)',
#          'movement_percent_change(t-9)', 'movement_percent_change(t-10)',
#          'density_weighted_movement(t-5)', 'density_weighted_movement(t-6)',
#          'density_weighted_movement(t-7)', 'density_weighted_movement(t-8)',
#          'density_weighted_movement(t-9)', 'density_weighted_movement(t-10)'],
#         dtype='object', length=115),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'count:poisson',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='count:poisson', random_state=0,
#                 reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#                 silent=True, subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': 'obj_count_auto_mov_gr_incid_7_mob5-10.pickle'},
#  {'columns_to_keep': ['incid_hosp',
#    'betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement',
#    'date',
#    'code_insee'],
#   'cols_to_lag': ['betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement'],
#   'incid_lag': True,
#   'incid_lag_start': 7,
#   'incid_lag_end': 1,
#   'col_lag_start': 10,
#   'col_lag_end': 4,
#   'depth': 3,
#   'MAE': 8.092842660516972,
#   'features': Index(['incid_hosp(t-5)', 'incid_hosp(t-6)', 'incid_hosp(t-7)',
#          'eigenvector_centrality-16_0(t-8)', 'movement_baseline(t-7)'],
#         dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'betweenness_centrality-16_0(t-4)',
#          'betweenness_centrality-16_0(t-5)', 'betweenness_centrality-16_0(t-6)',
#          ...
#          'movement_percent_change(t-8)', 'movement_percent_change(t-9)',
#          'movement_percent_change(t-10)', 'density_weighted_movement(t-4)',
#          'density_weighted_movement(t-5)', 'density_weighted_movement(t-6)',
#          'density_weighted_movement(t-7)', 'density_weighted_movement(t-8)',
#          'density_weighted_movement(t-9)', 'density_weighted_movement(t-10)'],
#         dtype='object', length=133),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'count:poisson',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='count:poisson', random_state=0,
#                 reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#                 silent=True, subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': 'obj_count_auto_mov_gr_incid_7_mob4-10.pickle'},
#  {'columns_to_keep': ['incid_hosp',
#    'betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement',
#    'date',
#    'code_insee'],
#   'cols_to_lag': ['betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement'],
#   'incid_lag': True,
#   'incid_lag_start': 7,
#   'incid_lag_end': 1,
#   'col_lag_start': 10,
#   'col_lag_end': 3,
#   'depth': 3,
#   'MAE': 8.063771308889132,
#   'features': Index(['incid_hosp(t-5)', 'incid_hosp(t-6)', 'incid_hosp(t-7)',
#          'eigenvector_centrality-16_0(t-8)', 'eigenvector_centrality-0_8(t-4)',
#          'movement_baseline(t-7)'],
#         dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'betweenness_centrality-16_0(t-3)',
#          'betweenness_centrality-16_0(t-4)', 'betweenness_centrality-16_0(t-5)',
#          ...
#          'movement_percent_change(t-9)', 'movement_percent_change(t-10)',
#          'density_weighted_movement(t-3)', 'density_weighted_movement(t-4)',
#          'density_weighted_movement(t-5)', 'density_weighted_movement(t-6)',
#          'density_weighted_movement(t-7)', 'density_weighted_movement(t-8)',
#          'density_weighted_movement(t-9)', 'density_weighted_movement(t-10)'],
#         dtype='object', length=151),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'count:poisson',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='count:poisson', random_state=0,
#                 reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#                 silent=True, subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': 'obj_count_auto_mov_gr_incid_7_mob3-10.pickle'},
#  {'columns_to_keep': ['incid_hosp',
#    'betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement',
#    'date',
#    'code_insee'],
#   'cols_to_lag': ['betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement'],
#   'incid_lag': True,
#   'incid_lag_start': 7,
#   'incid_lag_end': 1,
#   'col_lag_start': 11,
#   'col_lag_end': 10,
#   'depth': 3,
#   'MAE': 6.745924689992605,
#   'features': Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', 'incid_hosp(t-7)'], dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'betweenness_centrality-16_0(t-10)',
#          'betweenness_centrality-16_0(t-11)', 'closeness_centrality-16_0(t-10)',
#          'closeness_centrality-16_0(t-11)', 'degree_centrality-16_0(t-10)',
#          'degree_centrality-16_0(t-11)', 'eigenvector_centrality-16_0(t-10)',
#          'eigenvector_centrality-16_0(t-11)', 'betweenness_centrality-0_8(t-10)',
#          'betweenness_centrality-0_8(t-11)', 'closeness_centrality-0_8(t-10)',
#          'closeness_centrality-0_8(t-11)', 'degree_centrality-0_8(t-10)',
#          'degree_centrality-0_8(t-11)', 'eigenvector_centrality-0_8(t-10)',
#          'eigenvector_centrality-0_8(t-11)', 'betweenness_centrality-8_16(t-10)',
#          'betweenness_centrality-8_16(t-11)', 'closeness_centrality-8_16(t-10)',
#          'closeness_centrality-8_16(t-11)', 'degree_centrality-8_16(t-10)',
#          'degree_centrality-8_16(t-11)', 'eigenvector_centrality-8_16(t-10)',
#          'eigenvector_centrality-8_16(t-11)', 'length_km(t-10)',
#          'length_km(t-11)', 'movement(t-10)', 'movement(t-11)',
#          'movement_baseline(t-10)', 'movement_baseline(t-11)',
#          'movement_difference(t-10)', 'movement_difference(t-11)',
#          'movement_percent_change(t-10)', 'movement_percent_change(t-11)',
#          'density_weighted_movement(t-10)', 'density_weighted_movement(t-11)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'count:poisson',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='count:poisson', random_state=0,
#                 reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#                 silent=True, subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': 'obj_count_auto_mov_gr_incid_7_mob10-11.pickle'},
#  {'columns_to_keep': ['incid_hosp',
#    'betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement',
#    'date',
#    'code_insee'],
#   'cols_to_lag': ['betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement'],
#   'incid_lag': True,
#   'incid_lag_start': 7,
#   'incid_lag_end': 1,
#   'col_lag_start': 11,
#   'col_lag_end': 9,
#   'depth': 3,
#   'MAE': 6.9909209833994534,
#   'features': Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', 'incid_hosp(t-7)'], dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'betweenness_centrality-16_0(t-9)',
#          'betweenness_centrality-16_0(t-10)',
#          'betweenness_centrality-16_0(t-11)', 'closeness_centrality-16_0(t-9)',
#          'closeness_centrality-16_0(t-10)', 'closeness_centrality-16_0(t-11)',
#          'degree_centrality-16_0(t-9)', 'degree_centrality-16_0(t-10)',
#          'degree_centrality-16_0(t-11)', 'eigenvector_centrality-16_0(t-9)',
#          'eigenvector_centrality-16_0(t-10)',
#          'eigenvector_centrality-16_0(t-11)', 'betweenness_centrality-0_8(t-9)',
#          'betweenness_centrality-0_8(t-10)', 'betweenness_centrality-0_8(t-11)',
#          'closeness_centrality-0_8(t-9)', 'closeness_centrality-0_8(t-10)',
#          'closeness_centrality-0_8(t-11)', 'degree_centrality-0_8(t-9)',
#          'degree_centrality-0_8(t-10)', 'degree_centrality-0_8(t-11)',
#          'eigenvector_centrality-0_8(t-9)', 'eigenvector_centrality-0_8(t-10)',
#          'eigenvector_centrality-0_8(t-11)', 'betweenness_centrality-8_16(t-9)',
#          'betweenness_centrality-8_16(t-10)',
#          'betweenness_centrality-8_16(t-11)', 'closeness_centrality-8_16(t-9)',
#          'closeness_centrality-8_16(t-10)', 'closeness_centrality-8_16(t-11)',
#          'degree_centrality-8_16(t-9)', 'degree_centrality-8_16(t-10)',
#          'degree_centrality-8_16(t-11)', 'eigenvector_centrality-8_16(t-9)',
#          'eigenvector_centrality-8_16(t-10)',
#          'eigenvector_centrality-8_16(t-11)', 'length_km(t-9)',
#          'length_km(t-10)', 'length_km(t-11)', 'movement(t-9)', 'movement(t-10)',
#          'movement(t-11)', 'movement_baseline(t-9)', 'movement_baseline(t-10)',
#          'movement_baseline(t-11)', 'movement_difference(t-9)',
#          'movement_difference(t-10)', 'movement_difference(t-11)',
#          'movement_percent_change(t-9)', 'movement_percent_change(t-10)',
#          'movement_percent_change(t-11)', 'density_weighted_movement(t-9)',
#          'density_weighted_movement(t-10)', 'density_weighted_movement(t-11)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'count:poisson',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='count:poisson', random_state=0,
#                 reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#                 silent=True, subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': 'obj_count_auto_mov_gr_incid_7_mob9-11.pickle'},
#  {'columns_to_keep': ['incid_hosp',
#    'betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement',
#    'date',
#    'code_insee'],
#   'cols_to_lag': ['betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement'],
#   'incid_lag': True,
#   'incid_lag_start': 7,
#   'incid_lag_end': 1,
#   'col_lag_start': 11,
#   'col_lag_end': 8,
#   'depth': 3,
#   'MAE': 7.198216072649973,
#   'features': Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', 'incid_hosp(t-7)'], dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'betweenness_centrality-16_0(t-8)',
#          'betweenness_centrality-16_0(t-9)', 'betweenness_centrality-16_0(t-10)',
#          'betweenness_centrality-16_0(t-11)', 'closeness_centrality-16_0(t-8)',
#          'closeness_centrality-16_0(t-9)', 'closeness_centrality-16_0(t-10)',
#          'closeness_centrality-16_0(t-11)', 'degree_centrality-16_0(t-8)',
#          'degree_centrality-16_0(t-9)', 'degree_centrality-16_0(t-10)',
#          'degree_centrality-16_0(t-11)', 'eigenvector_centrality-16_0(t-8)',
#          'eigenvector_centrality-16_0(t-9)', 'eigenvector_centrality-16_0(t-10)',
#          'eigenvector_centrality-16_0(t-11)', 'betweenness_centrality-0_8(t-8)',
#          'betweenness_centrality-0_8(t-9)', 'betweenness_centrality-0_8(t-10)',
#          'betweenness_centrality-0_8(t-11)', 'closeness_centrality-0_8(t-8)',
#          'closeness_centrality-0_8(t-9)', 'closeness_centrality-0_8(t-10)',
#          'closeness_centrality-0_8(t-11)', 'degree_centrality-0_8(t-8)',
#          'degree_centrality-0_8(t-9)', 'degree_centrality-0_8(t-10)',
#          'degree_centrality-0_8(t-11)', 'eigenvector_centrality-0_8(t-8)',
#          'eigenvector_centrality-0_8(t-9)', 'eigenvector_centrality-0_8(t-10)',
#          'eigenvector_centrality-0_8(t-11)', 'betweenness_centrality-8_16(t-8)',
#          'betweenness_centrality-8_16(t-9)', 'betweenness_centrality-8_16(t-10)',
#          'betweenness_centrality-8_16(t-11)', 'closeness_centrality-8_16(t-8)',
#          'closeness_centrality-8_16(t-9)', 'closeness_centrality-8_16(t-10)',
#          'closeness_centrality-8_16(t-11)', 'degree_centrality-8_16(t-8)',
#          'degree_centrality-8_16(t-9)', 'degree_centrality-8_16(t-10)',
#          'degree_centrality-8_16(t-11)', 'eigenvector_centrality-8_16(t-8)',
#          'eigenvector_centrality-8_16(t-9)', 'eigenvector_centrality-8_16(t-10)',
#          'eigenvector_centrality-8_16(t-11)', 'length_km(t-8)', 'length_km(t-9)',
#          'length_km(t-10)', 'length_km(t-11)', 'movement(t-8)', 'movement(t-9)',
#          'movement(t-10)', 'movement(t-11)', 'movement_baseline(t-8)',
#          'movement_baseline(t-9)', 'movement_baseline(t-10)',
#          'movement_baseline(t-11)', 'movement_difference(t-8)',
#          'movement_difference(t-9)', 'movement_difference(t-10)',
#          'movement_difference(t-11)', 'movement_percent_change(t-8)',
#          'movement_percent_change(t-9)', 'movement_percent_change(t-10)',
# ...
#          'betweenness_centrality-8_16(t-18)',
#          'betweenness_centrality-8_16(t-19)',
#          'betweenness_centrality-8_16(t-20)',
#          'betweenness_centrality-8_16(t-21)', 'closeness_centrality-8_16(t-17)',
#          'closeness_centrality-8_16(t-18)', 'closeness_centrality-8_16(t-19)',
#          'closeness_centrality-8_16(t-20)', 'closeness_centrality-8_16(t-21)',
#          'degree_centrality-8_16(t-17)', 'degree_centrality-8_16(t-18)',
#          'degree_centrality-8_16(t-19)', 'degree_centrality-8_16(t-20)',
#          'degree_centrality-8_16(t-21)', 'eigenvector_centrality-8_16(t-17)',
#          'eigenvector_centrality-8_16(t-18)',
#          'eigenvector_centrality-8_16(t-19)',
#          'eigenvector_centrality-8_16(t-20)',
#          'eigenvector_centrality-8_16(t-21)', 'length_km(t-17)',
#          'length_km(t-18)', 'length_km(t-19)', 'length_km(t-20)',
#          'length_km(t-21)', 'movement(t-17)', 'movement(t-18)', 'movement(t-19)',
#          'movement(t-20)', 'movement(t-21)', 'movement_baseline(t-17)',
#          'movement_baseline(t-18)', 'movement_baseline(t-19)',
#          'movement_baseline(t-20)', 'movement_baseline(t-21)',
#          'movement_difference(t-17)', 'movement_difference(t-18)',
#          'movement_difference(t-19)', 'movement_difference(t-20)',
#          'movement_difference(t-21)', 'movement_percent_change(t-17)',
#          'movement_percent_change(t-18)', 'movement_percent_change(t-19)',
#          'movement_percent_change(t-20)', 'movement_percent_change(t-21)',
#          'density_weighted_movement(t-17)', 'density_weighted_movement(t-18)',
#          'density_weighted_movement(t-19)', 'density_weighted_movement(t-20)',
#          'density_weighted_movement(t-21)'],
#         dtype='object'),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'count:poisson',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='count:poisson', random_state=0,
#                 reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#                 silent=True, subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': 'obj_count_auto_mov_gr_incid_7_mob17-21.pickle'},
#  {'columns_to_keep': ['incid_hosp',
#    'betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement',
#    'date',
#    'code_insee'],
#   'cols_to_lag': ['betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement'],
#   'incid_lag': True,
#   'incid_lag_start': 7,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 16,
#   'depth': 3,
#   'MAE': 8.49427443963401,
#   'features': Index(['incid_hosp(t-2)', 'incid_hosp(t-3)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'closeness_centrality-16_0(t-19)',
#          'betweenness_centrality-8_16(t-16)', 'length_km(t-19)',
#          'density_weighted_movement(t-16)', 'density_weighted_movement(t-19)',
#          'density_weighted_movement(t-21)'],
#         dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'betweenness_centrality-16_0(t-16)',
#          'betweenness_centrality-16_0(t-17)',
#          'betweenness_centrality-16_0(t-18)',
#          ...
#          'movement_percent_change(t-18)', 'movement_percent_change(t-19)',
#          'movement_percent_change(t-20)', 'movement_percent_change(t-21)',
#          'density_weighted_movement(t-16)', 'density_weighted_movement(t-17)',
#          'density_weighted_movement(t-18)', 'density_weighted_movement(t-19)',
#          'density_weighted_movement(t-20)', 'density_weighted_movement(t-21)'],
#         dtype='object', length=115),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'count:poisson',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='count:poisson', random_state=0,
#                 reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#                 silent=True, subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': 'obj_count_auto_mov_gr_incid_7_mob16-21.pickle'},
#  {'columns_to_keep': ['incid_hosp',
#    'betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement',
#    'date',
#    'code_insee'],
#   'cols_to_lag': ['betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement'],
#   'incid_lag': True,
#   'incid_lag_start': 7,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 15,
#   'depth': 3,
#   'MAE': 8.199186900636109,
#   'features': Index(['incid_hosp(t-2)', 'incid_hosp(t-3)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'betweenness_centrality-16_0(t-20)',
#          'closeness_centrality-16_0(t-19)', 'betweenness_centrality-8_16(t-15)',
#          'length_km(t-19)', 'movement_difference(t-19)',
#          'density_weighted_movement(t-15)', 'density_weighted_movement(t-19)'],
#         dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'betweenness_centrality-16_0(t-15)',
#          'betweenness_centrality-16_0(t-16)',
#          'betweenness_centrality-16_0(t-17)',
#          ...
#          'movement_percent_change(t-19)', 'movement_percent_change(t-20)',
#          'movement_percent_change(t-21)', 'density_weighted_movement(t-15)',
#          'density_weighted_movement(t-16)', 'density_weighted_movement(t-17)',
#          'density_weighted_movement(t-18)', 'density_weighted_movement(t-19)',
#          'density_weighted_movement(t-20)', 'density_weighted_movement(t-21)'],
#         dtype='object', length=133),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'count:poisson',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='count:poisson', random_state=0,
#                 reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#                 silent=True, subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': 'obj_count_auto_mov_gr_incid_7_mob15-21.pickle'},
#  {'columns_to_keep': ['incid_hosp',
#    'betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement',
#    'date',
#    'code_insee'],
#   'cols_to_lag': ['betweenness_centrality-16_0',
#    'closeness_centrality-16_0',
#    'degree_centrality-16_0',
#    'eigenvector_centrality-16_0',
#    'betweenness_centrality-0_8',
#    'closeness_centrality-0_8',
#    'degree_centrality-0_8',
#    'eigenvector_centrality-0_8',
#    'betweenness_centrality-8_16',
#    'closeness_centrality-8_16',
#    'degree_centrality-8_16',
#    'eigenvector_centrality-8_16',
#    'length_km',
#    'movement',
#    'movement_baseline',
#    'movement_difference',
#    'movement_percent_change',
#    'density_weighted_movement'],
#   'incid_lag': True,
#   'incid_lag_start': 7,
#   'incid_lag_end': 1,
#   'col_lag_start': 21,
#   'col_lag_end': 14,
#   'depth': 3,
#   'MAE': 8.290163757211483,
#   'features': Index(['incid_hosp(t-2)', 'incid_hosp(t-3)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'betweenness_centrality-16_0(t-20)',
#          'eigenvector_centrality-16_0(t-19)',
#          'betweenness_centrality-8_16(t-14)',
#          'betweenness_centrality-8_16(t-15)', 'degree_centrality-8_16(t-14)',
#          'length_km(t-16)', 'movement_difference(t-19)',
#          'density_weighted_movement(t-15)', 'density_weighted_movement(t-19)',
#          'density_weighted_movement(t-21)'],
#         dtype='object'),
#   'model_input_cols': Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', 'incid_hosp(t-3)',
#          'incid_hosp(t-4)', 'incid_hosp(t-5)', 'incid_hosp(t-6)',
#          'incid_hosp(t-7)', 'betweenness_centrality-16_0(t-14)',
#          'betweenness_centrality-16_0(t-15)',
#          'betweenness_centrality-16_0(t-16)',
#          ...
#          'movement_percent_change(t-20)', 'movement_percent_change(t-21)',
#          'density_weighted_movement(t-14)', 'density_weighted_movement(t-15)',
#          'density_weighted_movement(t-16)', 'density_weighted_movement(t-17)',
#          'density_weighted_movement(t-18)', 'density_weighted_movement(t-19)',
#          'density_weighted_movement(t-20)', 'density_weighted_movement(t-21)'],
#         dtype='object', length=151),
#   'model_parameters': {'estimator__base_score': 0.5,
#    'estimator__booster': 'gbtree',
#    'estimator__colsample_bylevel': 1,
#    'estimator__colsample_bynode': 1,
#    'estimator__colsample_bytree': 1,
#    'estimator__gamma': 0.5,
#    'estimator__importance_type': 'gain',
#    'estimator__learning_rate': 0.03,
#    'estimator__max_delta_step': 0,
#    'estimator__max_depth': 3,
#    'estimator__min_child_weight': 1,
#    'estimator__missing': None,
#    'estimator__n_estimators': 1000,
#    'estimator__n_jobs': -1,
#    'estimator__nthread': None,
#    'estimator__objective': 'count:poisson',
#    'estimator__random_state': 0,
#    'estimator__reg_alpha': 0,
#    'estimator__reg_lambda': 1,
#    'estimator__scale_pos_weight': 1,
#    'estimator__seed': None,
#    'estimator__silent': True,
#    'estimator__subsample': 1.0,
#    'estimator__verbosity': 1,
#    'estimator__eval_metric': 'mae',
#    'estimator__cv': TimeSeriesSplit(max_train_size=None, n_splits=10),
#    'estimator': XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bynode=1, colsample_bytree=1,
#                 cv=TimeSeriesSplit(max_train_size=None, n_splits=10),
#                 eval_metric='mae', gamma=0.5, importance_type='gain',
#                 learning_rate=0.03, max_delta_step=0, max_depth=3,
#                 min_child_weight=1, missing=None, n_estimators=1000, n_jobs=-1,
#                 nthread=None, objective='count:poisson', random_state=0,
#                 reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#                 silent=True, subsample=1.0, verbosity=1),
#    'max_features': None,
#    'norm_order': 1,
#    'prefit': True,
#    'threshold': None},
#   'model_name': 'obj_count_auto_mov_gr_incid_7_mob14-21.pickle'}]

# %%
results =pd.DataFrame(results)

# %%
results
# Out:
#           MAE  col_lag_end  col_lag_start  \
# 0    6.697733            9             10
# 1    6.675655            8             10
# 2    8.135531            7             10
# 3    8.126969            6             10
# 4    8.013447            5             10
# 5    8.092843            4             10
# 6    8.063771            3             10
# 7    6.745925           10             11
# 8    6.990921            9             11
# 9    7.198216            8             11
# 10   8.508821            7             11
# 11  10.933785            6             11
# 12  10.869673            5             11
# 13  11.076610            4             11
# 14   6.722855           11             12
# 15   6.718100           10             12
# 16   6.588850            9             12
# 17   8.121975            8             12
# 18   8.302229            7             12
# 19   8.027672            6             12
# 20   8.097226            5             12
# 21   9.787589           12             13
# 22   9.754465           11             13
# 23  11.795998           10             13
# 24  14.039125            9             13
# 25   8.667019            8             13
# 26   9.137664            7             13
# 27   8.870299            6             13
# 28   8.038597           13             14
# 29   7.575185           12             14
# ..        ...          ...            ...
# 54   9.029054           11             17
# 55   9.160326           10             17
# 56   7.731988           17             18
# 57  14.007299           16             18
# 58   9.225416           15             18
# 59   9.215119           14             18
# 60   9.151792           13             18
# 61   9.113191           12             18
# 62   8.795359           11             18
# 63   7.973434           18             19
# 64   7.993173           17             19
# 65   8.058374           16             19
# 66   8.178172           15             19
# 67   9.027435           14             19
# 68   9.253244           13             19
# 69   9.040407           12             19
# 70   7.654407           19             20
# 71   7.963841           18             20
# 72   8.057162           17             20
# 73   7.819672           16             20
# 74   7.951254           15             20
# 75  10.856910           14             20
# 76  10.894871           13             20
# 77   8.205311           20             21
# 78   8.053276           19             21
# 79   8.140922           18             21
# 80   8.109693           17             21
# 81   8.494274           16             21
# 82   8.199187           15             21
# 83   8.290164           14             21
#
#                                           cols_to_lag  \
# 0   [betweenness_centrality-16_0, closeness_centra...
# 1   [betweenness_centrality-16_0, closeness_centra...
# 2   [betweenness_centrality-16_0, closeness_centra...
# 3   [betweenness_centrality-16_0, closeness_centra...
# 4   [betweenness_centrality-16_0, closeness_centra...
# 5   [betweenness_centrality-16_0, closeness_centra...
# 6   [betweenness_centrality-16_0, closeness_centra...
# 7   [betweenness_centrality-16_0, closeness_centra...
# 8   [betweenness_centrality-16_0, closeness_centra...
# 9   [betweenness_centrality-16_0, closeness_centra...
# 10  [betweenness_centrality-16_0, closeness_centra...
# 11  [betweenness_centrality-16_0, closeness_centra...
# 12  [betweenness_centrality-16_0, closeness_centra...
# 13  [betweenness_centrality-16_0, closeness_centra...
# 14  [betweenness_centrality-16_0, closeness_centra...
# 15  [betweenness_centrality-16_0, closeness_centra...
# 16  [betweenness_centrality-16_0, closeness_centra...
# 17  [betweenness_centrality-16_0, closeness_centra...
# 18  [betweenness_centrality-16_0, closeness_centra...
# 19  [betweenness_centrality-16_0, closeness_centra...
# 20  [betweenness_centrality-16_0, closeness_centra...
# 21  [betweenness_centrality-16_0, closeness_centra...
# 22  [betweenness_centrality-16_0, closeness_centra...
# 23  [betweenness_centrality-16_0, closeness_centra...
# 24  [betweenness_centrality-16_0, closeness_centra...
# 25  [betweenness_centrality-16_0, closeness_centra...
# 26  [betweenness_centrality-16_0, closeness_centra...
# 27  [betweenness_centrality-16_0, closeness_centra...
# 28  [betweenness_centrality-16_0, closeness_centra...
# 29  [betweenness_centrality-16_0, closeness_centra...
# ..                                                ...
# 54  [betweenness_centrality-16_0, closeness_centra...
# 55  [betweenness_centrality-16_0, closeness_centra...
# 56  [betweenness_centrality-16_0, closeness_centra...
# 57  [betweenness_centrality-16_0, closeness_centra...
# 58  [betweenness_centrality-16_0, closeness_centra...
# 59  [betweenness_centrality-16_0, closeness_centra...
# 60  [betweenness_centrality-16_0, closeness_centra...
# 61  [betweenness_centrality-16_0, closeness_centra...
# 62  [betweenness_centrality-16_0, closeness_centra...
# 63  [betweenness_centrality-16_0, closeness_centra...
# 64  [betweenness_centrality-16_0, closeness_centra...
# 65  [betweenness_centrality-16_0, closeness_centra...
# 66  [betweenness_centrality-16_0, closeness_centra...
# 67  [betweenness_centrality-16_0, closeness_centra...
# 68  [betweenness_centrality-16_0, closeness_centra...
# 69  [betweenness_centrality-16_0, closeness_centra...
# 70  [betweenness_centrality-16_0, closeness_centra...
# 71  [betweenness_centrality-16_0, closeness_centra...
# 72  [betweenness_centrality-16_0, closeness_centra...
# 73  [betweenness_centrality-16_0, closeness_centra...
# 74  [betweenness_centrality-16_0, closeness_centra...
# 75  [betweenness_centrality-16_0, closeness_centra...
# 76  [betweenness_centrality-16_0, closeness_centra...
# 77  [betweenness_centrality-16_0, closeness_centra...
# 78  [betweenness_centrality-16_0, closeness_centra...
# 79  [betweenness_centrality-16_0, closeness_centra...
# 80  [betweenness_centrality-16_0, closeness_centra...
# 81  [betweenness_centrality-16_0, closeness_centra...
# 82  [betweenness_centrality-16_0, closeness_centra...
# 83  [betweenness_centrality-16_0, closeness_centra...
#
#                                       columns_to_keep  depth  \
# 0   [incid_hosp, betweenness_centrality-16_0, clos...      3
# 1   [incid_hosp, betweenness_centrality-16_0, clos...      3
# 2   [incid_hosp, betweenness_centrality-16_0, clos...      3
# 3   [incid_hosp, betweenness_centrality-16_0, clos...      3
# 4   [incid_hosp, betweenness_centrality-16_0, clos...      3
# 5   [incid_hosp, betweenness_centrality-16_0, clos...      3
# 6   [incid_hosp, betweenness_centrality-16_0, clos...      3
# 7   [incid_hosp, betweenness_centrality-16_0, clos...      3
# 8   [incid_hosp, betweenness_centrality-16_0, clos...      3
# 9   [incid_hosp, betweenness_centrality-16_0, clos...      3
# 10  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 11  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 12  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 13  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 14  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 15  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 16  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 17  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 18  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 19  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 20  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 21  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 22  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 23  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 24  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 25  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 26  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 27  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 28  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 29  [incid_hosp, betweenness_centrality-16_0, clos...      3
# ..                                                ...    ...
# 54  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 55  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 56  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 57  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 58  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 59  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 60  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 61  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 62  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 63  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 64  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 65  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 66  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 67  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 68  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 69  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 70  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 71  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 72  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 73  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 74  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 75  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 76  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 77  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 78  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 79  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 80  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 81  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 82  [incid_hosp, betweenness_centrality-16_0, clos...      3
# 83  [incid_hosp, betweenness_centrality-16_0, clos...      3
#
#                                              features  incid_lag  \
# 0   Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', '...       True
# 1   Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', '...       True
# 2   Index(['incid_hosp(t-6)', 'incid_hosp(t-7)',
#  ...       True
# 3   Index(['incid_hosp(t-5)', 'incid_hosp(t-6)', '...       True
# 4   Index(['incid_hosp(t-5)', 'incid_hosp(t-6)', '...       True
# 5   Index(['incid_hosp(t-5)', 'incid_hosp(t-6)', '...       True
# 6   Index(['incid_hosp(t-5)', 'incid_hosp(t-6)', '...       True
# 7   Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', '...       True
# 8   Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', '...       True
# 9   Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', '...       True
# 10  Index(['incid_hosp(t-6)', 'incid_hosp(t-7)',
#  ...       True
# 11  Index(['incid_hosp(t-6)', 'incid_hosp(t-7)',
#  ...       True
# 12  Index(['incid_hosp(t-5)', 'incid_hosp(t-6)', '...       True
# 13  Index(['incid_hosp(t-5)', 'incid_hosp(t-6)', '...       True
# 14  Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', '...       True
# 15  Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', '...       True
# 16  Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', '...       True
# 17  Index(['incid_hosp(t-5)', 'incid_hosp(t-6)', '...       True
# 18  Index(['incid_hosp(t-5)', 'incid_hosp(t-6)', '...       True
# 19  Index(['incid_hosp(t-5)', 'incid_hosp(t-6)', '...       True
# 20  Index(['incid_hosp(t-5)', 'incid_hosp(t-6)', '...       True
# 21  Index(['incid_hosp(t-6)', 'incid_hosp(t-7)', '...       True
# 22  Index(['incid_hosp(t-6)', 'incid_hosp(t-7)', '...       True
# 23  Index(['incid_hosp(t-6)', 'incid_hosp(t-7)',
#  ...       True
# 24  Index(['incid_hosp(t-5)', 'incid_hosp(t-6)', '...       True
# 25  Index(['incid_hosp(t-5)', 'incid_hosp(t-6)', '...       True
# 26  Index(['incid_hosp(t-5)', 'incid_hosp(t-6)', '...       True
# 27  Index(['incid_hosp(t-5)', 'incid_hosp(t-6)', '...       True
# 28  Index(['incid_hosp(t-6)', 'incid_hosp(t-7)', '...       True
# 29  Index(['incid_hosp(t-6)', 'incid_hosp(t-7)', '...       True
# ..                                                ...        ...
# 54  Index(['incid_hosp(t-2)', 'incid_hosp(t-6)', '...       True
# 55  Index(['incid_hosp(t-2)', 'incid_hosp(t-6)', '...       True
# 56  Index(['incid_hosp(t-6)', 'incid_hosp(t-7)',
#  ...       True
# 57  Index(['incid_hosp(t-6)', 'incid_hosp(t-7)', '...       True
# 58  Index(['incid_hosp(t-5)', 'incid_hosp(t-6)', '...       True
# 59  Index(['incid_hosp(t-5)', 'incid_hosp(t-6)', '...       True
# 60  Index(['incid_hosp(t-5)', 'incid_hosp(t-6)', '...       True
# 61  Index(['incid_hosp(t-2)', 'incid_hosp(t-5)', '...       True
# 62  Index(['incid_hosp(t-2)', 'incid_hosp(t-5)', '...       True
# 63  Index(['incid_hosp(t-6)', 'incid_hosp(t-7)'], ...       True
# 64  Index(['incid_hosp(t-6)', 'incid_hosp(t-7)'], ...       True
# 65  Index(['incid_hosp(t-6)', 'incid_hosp(t-7)',
#  ...       True
# 66  Index(['incid_hosp(t-6)', 'incid_hosp(t-7)',
#  ...       True
# 67  Index(['incid_hosp(t-6)', 'incid_hosp(t-7)',
#  ...       True
# 68  Index(['incid_hosp(t-6)', 'incid_hosp(t-7)',
#  ...       True
# 69  Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', '...       True
# 70  Index(['incid_hosp(t-6)', 'incid_hosp(t-7)'], ...       True
# 71  Index(['incid_hosp(t-6)', 'incid_hosp(t-7)',
#  ...       True
# 72  Index(['incid_hosp(t-6)', 'incid_hosp(t-7)', '...       True
# 73  Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', '...       True
# 74  Index(['incid_hosp(t-1)', 'incid_hosp(t-6)', '...       True
# 75  Index(['incid_hosp(t-6)', 'incid_hosp(t-7)', '...       True
# 76  Index(['incid_hosp(t-6)', 'incid_hosp(t-7)', '...       True
# 77  Index(['incid_hosp(t-2)', 'incid_hosp(t-3)', '...       True
# 78  Index(['incid_hosp(t-2)', 'incid_hosp(t-3)', '...       True
# 79  Index(['incid_hosp(t-2)', 'incid_hosp(t-3)', '...       True
# 80  Index(['incid_hosp(t-2)', 'incid_hosp(t-3)', '...       True
# 81  Index(['incid_hosp(t-2)', 'incid_hosp(t-3)', '...       True
# 82  Index(['incid_hosp(t-2)', 'incid_hosp(t-3)', '...       True
# 83  Index(['incid_hosp(t-2)', 'incid_hosp(t-3)', '...       True
#
#     incid_lag_end  incid_lag_start  \
# 0               1                7
# 1               1                7
# 2               1                7
# 3               1                7
# 4               1                7
# 5               1                7
# 6               1                7
# 7               1                7
# 8               1                7
# 9               1                7
# 10              1                7
# 11              1                7
# 12              1                7
# 13              1                7
# 14              1                7
# 15              1                7
# 16              1                7
# 17              1                7
# 18              1                7
# 19              1                7
# 20              1                7
# 21              1                7
# 22              1                7
# 23              1                7
# 24              1                7
# 25              1                7
# 26              1                7
# 27              1                7
# 28              1                7
# 29              1                7
# ..            ...              ...
# 54              1                7
# 55              1                7
# 56              1                7
# 57              1                7
# 58              1                7
# 59              1                7
# 60              1                7
# 61              1                7
# 62              1                7
# 63              1                7
# 64              1                7
# 65              1                7
# 66              1                7
# 67              1                7
# 68              1                7
# 69              1                7
# 70              1                7
# 71              1                7
# 72              1                7
# 73              1                7
# 74              1                7
# 75              1                7
# 76              1                7
# 77              1                7
# 78              1                7
# 79              1                7
# 80              1                7
# 81              1                7
# 82              1                7
# 83              1                7
#
#                                      model_input_cols  \
# 0   Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 1   Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 2   Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 3   Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 4   Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 5   Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 6   Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 7   Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 8   Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 9   Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 10  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 11  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 12  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 13  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 14  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 15  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 16  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 17  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 18  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 19  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 20  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 21  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 22  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 23  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 24  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 25  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 26  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 27  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 28  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 29  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# ..                                                ...
# 54  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 55  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 56  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 57  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 58  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 59  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 60  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 61  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 62  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 63  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 64  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 65  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 66  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 67  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 68  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 69  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 70  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 71  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 72  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 73  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 74  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 75  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 76  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 77  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 78  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 79  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 80  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 81  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 82  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
# 83  Index(['incid_hosp(t-1)', 'incid_hosp(t-2)', '...
#
#                                        model_name  \
# 0    obj_count_auto_mov_gr_incid_7_mob9-10.pickle
# 1    obj_count_auto_mov_gr_incid_7_mob8-10.pickle
# 2    obj_count_auto_mov_gr_incid_7_mob7-10.pickle
# 3    obj_count_auto_mov_gr_incid_7_mob6-10.pickle
# 4    obj_count_auto_mov_gr_incid_7_mob5-10.pickle
# 5    obj_count_auto_mov_gr_incid_7_mob4-10.pickle
# 6    obj_count_auto_mov_gr_incid_7_mob3-10.pickle
# 7   obj_count_auto_mov_gr_incid_7_mob10-11.pickle
# 8    obj_count_auto_mov_gr_incid_7_mob9-11.pickle
# 9    obj_count_auto_mov_gr_incid_7_mob8-11.pickle
# 10   obj_count_auto_mov_gr_incid_7_mob7-11.pickle
# 11   obj_count_auto_mov_gr_incid_7_mob6-11.pickle
# 12   obj_count_auto_mov_gr_incid_7_mob5-11.pickle
# 13   obj_count_auto_mov_gr_incid_7_mob4-11.pickle
# 14  obj_count_auto_mov_gr_incid_7_mob11-12.pickle
# 15  obj_count_auto_mov_gr_incid_7_mob10-12.pickle
# 16   obj_count_auto_mov_gr_incid_7_mob9-12.pickle
# 17   obj_count_auto_mov_gr_incid_7_mob8-12.pickle
# 18   obj_count_auto_mov_gr_incid_7_mob7-12.pickle
# 19   obj_count_auto_mov_gr_incid_7_mob6-12.pickle
# 20   obj_count_auto_mov_gr_incid_7_mob5-12.pickle
# 21  obj_count_auto_mov_gr_incid_7_mob12-13.pickle
# 22  obj_count_auto_mov_gr_incid_7_mob11-13.pickle
# 23  obj_count_auto_mov_gr_incid_7_mob10-13.pickle
# 24   obj_count_auto_mov_gr_incid_7_mob9-13.pickle
# 25   obj_count_auto_mov_gr_incid_7_mob8-13.pickle
# 26   obj_count_auto_mov_gr_incid_7_mob7-13.pickle
# 27   obj_count_auto_mov_gr_incid_7_mob6-13.pickle
# 28  obj_count_auto_mov_gr_incid_7_mob13-14.pickle
# 29  obj_count_auto_mov_gr_incid_7_mob12-14.pickle
# ..                                            ...
# 54  obj_count_auto_mov_gr_incid_7_mob11-17.pickle
# 55  obj_count_auto_mov_gr_incid_7_mob10-17.pickle
# 56  obj_count_auto_mov_gr_incid_7_mob17-18.pickle
# 57  obj_count_auto_mov_gr_incid_7_mob16-18.pickle
# 58  obj_count_auto_mov_gr_incid_7_mob15-18.pickle
# 59  obj_count_auto_mov_gr_incid_7_mob14-18.pickle
# 60  obj_count_auto_mov_gr_incid_7_mob13-18.pickle
# 61  obj_count_auto_mov_gr_incid_7_mob12-18.pickle
# 62  obj_count_auto_mov_gr_incid_7_mob11-18.pickle
# 63  obj_count_auto_mov_gr_incid_7_mob18-19.pickle
# 64  obj_count_auto_mov_gr_incid_7_mob17-19.pickle
# 65  obj_count_auto_mov_gr_incid_7_mob16-19.pickle
# 66  obj_count_auto_mov_gr_incid_7_mob15-19.pickle
# 67  obj_count_auto_mov_gr_incid_7_mob14-19.pickle
# 68  obj_count_auto_mov_gr_incid_7_mob13-19.pickle
# 69  obj_count_auto_mov_gr_incid_7_mob12-19.pickle
# 70  obj_count_auto_mov_gr_incid_7_mob19-20.pickle
# 71  obj_count_auto_mov_gr_incid_7_mob18-20.pickle
# 72  obj_count_auto_mov_gr_incid_7_mob17-20.pickle
# 73  obj_count_auto_mov_gr_incid_7_mob16-20.pickle
# 74  obj_count_auto_mov_gr_incid_7_mob15-20.pickle
# 75  obj_count_auto_mov_gr_incid_7_mob14-20.pickle
# 76  obj_count_auto_mov_gr_incid_7_mob13-20.pickle
# 77  obj_count_auto_mov_gr_incid_7_mob20-21.pickle
# 78  obj_count_auto_mov_gr_incid_7_mob19-21.pickle
# 79  obj_count_auto_mov_gr_incid_7_mob18-21.pickle
# 80  obj_count_auto_mov_gr_incid_7_mob17-21.pickle
# 81  obj_count_auto_mov_gr_incid_7_mob16-21.pickle
# 82  obj_count_auto_mov_gr_incid_7_mob15-21.pickle
# 83  obj_count_auto_mov_gr_incid_7_mob14-21.pickle
#
#                                      model_parameters
# 0   {'estimator__base_score': 0.5, 'estimator__boo...
# 1   {'estimator__base_score': 0.5, 'estimator__boo...
# 2   {'estimator__base_score': 0.5, 'estimator__boo...
# 3   {'estimator__base_score': 0.5, 'estimator__boo...
# 4   {'estimator__base_score': 0.5, 'estimator__boo...
# 5   {'estimator__base_score': 0.5, 'estimator__boo...
# 6   {'estimator__base_score': 0.5, 'estimator__boo...
# 7   {'estimator__base_score': 0.5, 'estimator__boo...
# 8   {'estimator__base_score': 0.5, 'estimator__boo...
# 9   {'estimator__base_score': 0.5, 'estimator__boo...
# 10  {'estimator__base_score': 0.5, 'estimator__boo...
# 11  {'estimator__base_score': 0.5, 'estimator__boo...
# 12  {'estimator__base_score': 0.5, 'estimator__boo...
# 13  {'estimator__base_score': 0.5, 'estimator__boo...
# 14  {'estimator__base_score': 0.5, 'estimator__boo...
# 15  {'estimator__base_score': 0.5, 'estimator__boo...
# 16  {'estimator__base_score': 0.5, 'estimator__boo...
# 17  {'estimator__base_score': 0.5, 'estimator__boo...
# 18  {'estimator__base_score': 0.5, 'estimator__boo...
# 19  {'estimator__base_score': 0.5, 'estimator__boo...
# 20  {'estimator__base_score': 0.5, 'estimator__boo...
# 21  {'estimator__base_score': 0.5, 'estimator__boo...
# 22  {'estimator__base_score': 0.5, 'estimator__boo...
# 23  {'estimator__base_score': 0.5, 'estimator__boo...
# 24  {'estimator__base_score': 0.5, 'estimator__boo...
# 25  {'estimator__base_score': 0.5, 'estimator__boo...
# 26  {'estimator__base_score': 0.5, 'estimator__boo...
# 27  {'estimator__base_score': 0.5, 'estimator__boo...
# 28  {'estimator__base_score': 0.5, 'estimator__boo...
# 29  {'estimator__base_score': 0.5, 'estimator__boo...
# ..                                                ...
# 54  {'estimator__base_score': 0.5, 'estimator__boo...
# 55  {'estimator__base_score': 0.5, 'estimator__boo...
# 56  {'estimator__base_score': 0.5, 'estimator__boo...
# 57  {'estimator__base_score': 0.5, 'estimator__boo...
# 58  {'estimator__base_score': 0.5, 'estimator__boo...
# 59  {'estimator__base_score': 0.5, 'estimator__boo...
# 60  {'estimator__base_score': 0.5, 'estimator__boo...
# 61  {'estimator__base_score': 0.5, 'estimator__boo...
# 62  {'estimator__base_score': 0.5, 'estimator__boo...
# 63  {'estimator__base_score': 0.5, 'estimator__boo...
# 64  {'estimator__base_score': 0.5, 'estimator__boo...
# 65  {'estimator__base_score': 0.5, 'estimator__boo...
# 66  {'estimator__base_score': 0.5, 'estimator__boo...
# 67  {'estimator__base_score': 0.5, 'estimator__boo...
# 68  {'estimator__base_score': 0.5, 'estimator__boo...
# 69  {'estimator__base_score': 0.5, 'estimator__boo...
# 70  {'estimator__base_score': 0.5, 'estimator__boo...
# 71  {'estimator__base_score': 0.5, 'estimator__boo...
# 72  {'estimator__base_score': 0.5, 'estimator__boo...
# 73  {'estimator__base_score': 0.5, 'estimator__boo...
# 74  {'estimator__base_score': 0.5, 'estimator__boo...
# 75  {'estimator__base_score': 0.5, 'estimator__boo...
# 76  {'estimator__base_score': 0.5, 'estimator__boo...
# 77  {'estimator__base_score': 0.5, 'estimator__boo...
# 78  {'estimator__base_score': 0.5, 'estimator__boo...
# 79  {'estimator__base_score': 0.5, 'estimator__boo...
# 80  {'estimator__base_score': 0.5, 'estimator__boo...
# 81  {'estimator__base_score': 0.5, 'estimator__boo...
# 82  {'estimator__base_score': 0.5, 'estimator__boo...
# 83  {'estimator__base_score': 0.5, 'estimator__boo...
#
# [84 rows x 13 columns]

# %%
results.to_csv('data/reports/report4.csv')

# %%
# depth vary, without looping over mobility windows
scores =  []
cols = ['incid_hosp', 
       'betweenness_centrality-16_0', 'closeness_centrality-16_0',
       'degree_centrality-16_0', 'eigenvector_centrality-16_0',
       'betweenness_centrality-0_8', 'closeness_centrality-0_8',
       'degree_centrality-0_8', 'eigenvector_centrality-0_8',
       'betweenness_centrality-8_16', 'closeness_centrality-8_16',
       'degree_centrality-8_16', 'eigenvector_centrality-8_16', 
       'length_km', 'movement', 'movement_baseline', 'movement_difference',
       'movement_percent_change', 'density_weighted_movement','date','code_insee']

cols_to_lag = ['betweenness_centrality-16_0', 'closeness_centrality-16_0',
               'degree_centrality-16_0', 'eigenvector_centrality-16_0',
               'betweenness_centrality-0_8', 'closeness_centrality-0_8',
               'degree_centrality-0_8', 'eigenvector_centrality-0_8',
               'betweenness_centrality-8_16', 'closeness_centrality-8_16',
               'degree_centrality-8_16', 'eigenvector_centrality-8_16', 'length_km', 'movement', 'movement_baseline', 'movement_difference',
       'movement_percent_change', 'density_weighted_movement']
for i in range(3,30):
    dico = expe(cols, cols_to_lag ,incid_lag = True, incid_lag_start = 7,
        incid_lag_end = 1, col_lag_start = 21, col_lag_end = 18, depth = i)

    scores.append(dico)
# Out:
# MAE: 8.11 (231, 98)
# MAE: 8.23 (231, 98)
# MAE: 8.26 (231, 98)
# MAE: 8.44 (231, 98)
# MAE: 9.07 (231, 98)
# MAE: 8.73 (231, 98)
# MAE: 8.81 (231, 98)
# MAE: 8.78 (231, 98)
# MAE: 8.84 (231, 98)
# MAE: 8.77 (231, 98)
# MAE: 8.74 (231, 98)
# MAE: 8.78 (231, 98)
# MAE: 8.78 (231, 98)
# MAE: 8.78 (231, 98)
# MAE: 8.78 (231, 98)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-803-fbf1065cb13d> in <module>
#      20 for i in range(3,30):
#      21     dico = expe(cols, cols_to_lag ,incid_lag = True, incid_lag_start = 7,
# ---> 22         incid_lag_end = 1, col_lag_start = 21, col_lag_end = 18, depth = i)
#      23
#      24     scores.append(dico)
#
# <ipython-input-796-64febd096e2f> in expe(columns_to_keep, cols_to_lag, incid_lag, incid_lag_start, incid_lag_end, col_lag_start, col_lag_end, depth)
#       7
#       8
# ----> 9     train, val, train_w_c, val_w_c = split_for_test(data,split_date = '2020-04-20' )
#      10     #print(train.columns)
#      11
#
# <ipython-input-793-39a80b300517> in split_for_test(data, split_date)
#       8     # but also all the other columns the predictor won't take into account
#       9     train.drop(['date','code_insee'], inplace = True, axis = 1)
# ---> 10     val.drop(['date','code_insee'], inplace  = True, axis =1)
#      11
#      12     return train, val, train_with_codes, val_with_codes
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3781
#    3782         if inplace:
# -> 3783             self._update_inplace(obj)
#    3784         else:
#    3785             return obj
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _update_inplace(self, result, verify_is_copy)
#    3854         self._clear_item_cache()
#    3855         self._data = getattr(result, '_data', result)
# -> 3856         self._maybe_update_cacher(verify_is_copy=verify_is_copy)
#    3857
#    3858     def add_prefix(self, prefix):
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _maybe_update_cacher(self, clear, verify_is_copy)
#    3142
#    3143         if verify_is_copy:
# -> 3144             self._check_setitem_copy(stacklevel=5, t='referant')
#    3145
#    3146         if clear:
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _check_setitem_copy(self, stacklevel, t, force)
#    3243             # the copy weakref
#    3244             try:
# -> 3245                 gc.collect(2)
#    3246                 if not gc.get_referents(self._is_copy()):
#    3247                     self._is_copy = None
#
# KeyboardInterrupt:
